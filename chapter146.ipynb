# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sIMG_2168.jpg',0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sIMG_2164.png',0)
# Output dtype = cv2.CV_8U
sobelx8u = cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)
# Output dtype = cv2.CV_64F. Then take its absolute and convert to cv2.CV_8U
sobelx64f = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
abs_sobel64f = np.absolute(sobelx64f)
sobel_8u = np.uint8(abs_sobel64f)
plt.subplot(1,3,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobelx8u,cmap = 'gray')
plt.title('Sobel CV_8U'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobel_8u,cmap = 'gray')
plt.title('Sobel abs(CV_64F)'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sIMG_2177.jpg',0)
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('Canopic-Jar.jpg',0)
# Output dtype = cv2.CV_8U
sobelx8u = cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)
# Output dtype = cv2.CV_64F. Then take its absolute and convert to cv2.CV_8U
sobelx64f = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
abs_sobel64f = np.absolute(sobelx64f)
sobel_8u = np.uint8(abs_sobel64f)
plt.subplot(1,3,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(sobelx8u,cmap = 'gray')
plt.title('Sobel CV_8U'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(sobel_8u,cmap = 'gray')
plt.title('Sobel abs(CV_64F)'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
print(contours)
# Out:
# (array([[[372, 477]],
#
#        [[373, 476]],
#
#        [[374, 477]],
#
#        [[373, 478]]], dtype=int32), array([[[367, 463]]], dtype=int32), array([[[357, 463]],
#
#        [[358, 462]],
#
#        [[359, 463]],
#
#        [[358, 464]]], dtype=int32), array([[[360, 457]]], dtype=int32), array([[[394, 453]],
#
#        [[394, 455]],
#
#        [[395, 455]],
#
#        [[395, 453]]], dtype=int32), array([[[394, 449]],
#
#        [[394, 450]]], dtype=int32), array([[[402, 445]],
#
#        [[403, 444]],
#
#        [[404, 444]],
#
#        [[405, 445]],
#
#        [[405, 447]],
#
#        [[404, 448]],
#
#        [[402, 446]]], dtype=int32), array([[[348, 434]],
#
#        [[348, 435]]], dtype=int32), array([[[393, 432]],
#
#        [[394, 432]]], dtype=int32), array([[[404, 430]],
#
#        [[405, 429]],
#
#        [[406, 430]],
#
#        [[405, 431]]], dtype=int32), array([[[413, 427]],
#
#        [[415, 429]],
#
#        [[414, 430]],
#
#        [[414, 432]],
#
#        [[410, 436]],
#
#        [[408, 436]],
#
#        [[407, 435]],
#
#        [[407, 434]],
#
#        [[410, 431]],
#
#        [[410, 430]]], dtype=int32), array([[[336, 427]],
#
#        [[337, 427]]], dtype=int32), array([[[327, 424]],
#
#        [[328, 423]],
#
#        [[329, 423]],
#
#        [[330, 424]],
#
#        [[329, 425]],
#
#        [[328, 425]]], dtype=int32), array([[[403, 422]],
#
#        [[404, 423]],
#
#        [[404, 425]],
#
#        [[403, 426]],
#
#        [[402, 426]],
#
#        [[401, 425]],
#
#        [[401, 424]]], dtype=int32), array([[[395, 421]],
#
#        [[395, 427]],
#
#        [[396, 426]],
#
#        [[396, 423]],
#
#        [[397, 422]],
#
#        [[397, 421]]], dtype=int32), array([[[415, 415]],
#
#        [[416, 414]],
#
#        [[417, 414]],
#
#        [[418, 415]],
#
#        [[417, 416]],
#
#        [[416, 416]]], dtype=int32), array([[[412, 413]],
#
#        [[413, 412]],
#
#        [[414, 412]],
#
#        [[416, 414]],
#
#        [[413, 417]],
#
#        [[412, 417]],
#
#        [[411, 416]],
#
#        [[412, 415]]], dtype=int32), array([[[424, 409]],
#
#        [[425, 408]],
#
#        [[426, 408]],
#
#        [[427, 409]],
#
#        [[426, 410]],
#
#        [[426, 411]],
#
#        [[427, 412]],
#
#        [[426, 413]],
#
#        [[425, 413]],
#
#        [[424, 412]],
#
#        [[424, 411]],
#
#        [[420, 411]],
#
#        [[419, 410]],
#
#        [[420, 409]]], dtype=int32), array([[[382, 408]],
#
#        [[383, 408]],
#
#        [[384, 409]],
#
#        [[384, 411]],
#
#        [[382, 413]],
#
#        [[380, 411]],
#
#        [[380, 410]]], dtype=int32), array([[[398, 407]]], dtype=int32), array([[[384, 406]],
#
#        [[384, 407]],
#
#        [[383, 408]],
#
#        [[382, 408]],
#
#        [[381, 407]],
#
#        [[380, 407]],
#
#        [[380, 412]],
#
#        [[381, 413]],
#
#        [[381, 415]],
#
#        [[382, 415]],
#
#        [[383, 414]],
#
#        [[384, 415]],
#
#        [[383, 414]],
#
#        [[383, 413]],
#
#        [[384, 412]],
#
#        [[385, 412]],
#
#        [[386, 411]],
#
#        [[387, 411]],
#
#        [[388, 412]],
#
#        [[392, 412]],
#
#        [[393, 413]],
#
#        [[393, 414]],
#
#        [[392, 415]],
#
#        [[390, 415]],
#
#        [[391, 416]],
#
#        [[392, 415]],
#
#        [[393, 415]],
#
#        [[394, 414]],
#
#        [[395, 415]],
#
#        [[396, 415]],
#
#        [[396, 411]],
#
#        [[395, 411]],
#
#        [[394, 410]],
#
#        [[394, 407]],
#
#        [[393, 408]],
#
#        [[393, 409]],
#
#        [[392, 410]],
#
#        [[388, 410]],
#
#        [[387, 411]],
#
#        [[385, 411]],
#
#        [[384, 410]],
#
#        [[384, 409]],
#
#        [[385, 408]],
#
#        [[384, 407]]], dtype=int32), array([[[418, 405]],
#
#        [[419, 404]],
#
#        [[420, 405]],
#
#        [[419, 406]]], dtype=int32), array([[[414, 404]],
#
#        [[415, 403]],
#
#        [[416, 404]],
#
#        [[416, 407]],
#
#        [[417, 408]],
#
#        [[417, 409]],
#
#        [[416, 410]],
#
#        [[414, 410]],
#
#        [[413, 409]],
#
#        [[412, 410]],
#
#        [[410, 408]],
#
#        [[411, 407]],
#
#        [[411, 405]],
#
#        [[412, 404]]], dtype=int32), array([[[396, 401]],
#
#        [[396, 402]],
#
#        [[397, 401]]], dtype=int32), array([[[321, 400]],
#
#        [[322, 399]],
#
#        [[323, 400]],
#
#        [[322, 401]]], dtype=int32), array([[[400, 399]]], dtype=int32), array([[[414, 397]],
#
#        [[415, 398]],
#
#        [[415, 399]],
#
#        [[416, 400]],
#
#        [[415, 401]],
#
#        [[413, 401]],
#
#        [[412, 400]],
#
#        [[412, 399]]], dtype=int32), array([[[423, 397]],
#
#        [[424, 396]],
#
#        [[425, 397]],
#
#        [[424, 398]]], dtype=int32), array([[[418, 396]],
#
#        [[420, 398]],
#
#        [[418, 400]],
#
#        [[416, 400]],
#
#        [[415, 399]]], dtype=int32), array([[[389, 397]],
#
#        [[390, 397]]], dtype=int32), array([[[426, 395]],
#
#        [[427, 394]],
#
#        [[428, 395]],
#
#        [[427, 396]]], dtype=int32), array([[[407, 395]],
#
#        [[405, 397]],
#
#        [[405, 398]],
#
#        [[404, 399]],
#
#        [[406, 399]],
#
#        [[407, 398]]], dtype=int32), array([[[401, 395]],
#
#        [[400, 396]],
#
#        [[400, 397]],
#
#        [[401, 397]],
#
#        [[402, 396]],
#
#        [[403, 396]],
#
#        [[403, 395]]], dtype=int32), array([[[407, 392]]], dtype=int32), array([[[402, 392]]], dtype=int32), array([[[395, 392]],
#
#        [[395, 393]],
#
#        [[399, 393]],
#
#        [[398, 392]]], dtype=int32), array([[[390, 392]],
#
#        [[390, 393]],
#
#        [[391, 393]]], dtype=int32), array([[[318, 392]],
#
#        [[319, 391]],
#
#        [[320, 392]],
#
#        [[319, 393]]], dtype=int32), array([[[414, 391]],
#
#        [[415, 390]],
#
#        [[416, 391]],
#
#        [[415, 392]]], dtype=int32), array([[[411, 391]]], dtype=int32), array([[[424, 390]],
#
#        [[425, 389]],
#
#        [[427, 391]],
#
#        [[426, 392]],
#
#        [[425, 392]],
#
#        [[424, 391]]], dtype=int32), array([[[423, 389]],
#
#        [[424, 390]],
#
#        [[424, 392]],
#
#        [[423, 393]],
#
#        [[422, 393]],
#
#        [[421, 394]],
#
#        [[417, 394]],
#
#        [[415, 392]],
#
#        [[416, 391]],
#
#        [[421, 391]]], dtype=int32), array([[[427, 388]],
#
#        [[428, 387]],
#
#        [[429, 387]],
#
#        [[430, 388]],
#
#        [[430, 389]],
#
#        [[428, 391]],
#
#        [[427, 390]]], dtype=int32), array([[[391, 387]]], dtype=int32), array([[[420, 384]],
#
#        [[420, 385]],
#
#        [[421, 385]]], dtype=int32), array([[[307, 384]],
#
#        [[308, 383]],
#
#        [[309, 383]],
#
#        [[310, 384]],
#
#        [[310, 388]],
#
#        [[309, 389]],
#
#        [[308, 388]],
#
#        [[308, 385]]], dtype=int32), array([[[363, 383]]], dtype=int32), array([[[368, 380]],
#
#        [[367, 381]],
#
#        [[365, 381]],
#
#        [[365, 382]],
#
#        [[366, 382]],
#
#        [[367, 381]],
#
#        [[369, 381]],
#
#        [[369, 380]]], dtype=int32), array([[[360, 377]],
#
#        [[360, 378]]], dtype=int32), array([[[416, 376]],
#
#        [[418, 376]]], dtype=int32), array([[[327, 376]],
#
#        [[328, 375]],
#
#        [[329, 375]],
#
#        [[330, 376]],
#
#        [[329, 377]],
#
#        [[328, 377]]], dtype=int32), array([[[310, 376]],
#
#        [[311, 375]],
#
#        [[312, 376]],
#
#        [[312, 379]],
#
#        [[311, 380]],
#
#        [[310, 379]]], dtype=int32), array([[[369, 375]],
#
#        [[368, 376]],
#
#        [[368, 377]],
#
#        [[369, 378]],
#
#        [[370, 377]],
#
#        [[370, 376]]], dtype=int32), array([[[372, 373]],
#
#        [[373, 374]],
#
#        [[373, 377]],
#
#        [[375, 377]],
#
#        [[375, 375]],
#
#        [[376, 374]],
#
#        [[376, 373]]], dtype=int32), array([[[424, 371]],
#
#        [[421, 374]],
#
#        [[423, 376]],
#
#        [[424, 376]],
#
#        [[424, 375]],
#
#        [[423, 374]],
#
#        [[424, 373]]], dtype=int32), array([[[360, 370]],
#
#        [[359, 371]],
#
#        [[359, 373]],
#
#        [[360, 373]],
#
#        [[361, 374]],
#
#        [[366, 374]],
#
#        [[367, 373]],
#
#        [[366, 373]],
#
#        [[365, 372]],
#
#        [[364, 372]],
#
#        [[362, 370]]], dtype=int32), array([[[309, 369]],
#
#        [[310, 368]],
#
#        [[311, 369]],
#
#        [[311, 374]],
#
#        [[310, 375]],
#
#        [[310, 378]],
#
#        [[309, 379]],
#
#        [[309, 380]],
#
#        [[308, 381]],
#
#        [[307, 381]],
#
#        [[306, 380]],
#
#        [[306, 376]],
#
#        [[307, 375]],
#
#        [[306, 374]],
#
#        [[307, 373]],
#
#        [[309, 373]]], dtype=int32), array([[[416, 367]],
#
#        [[417, 368]],
#
#        [[418, 368]],
#
#        [[419, 367]],
#
#        [[420, 367]]], dtype=int32), array([[[390, 367]],
#
#        [[389, 368]],
#
#        [[386, 368]],
#
#        [[388, 370]],
#
#        [[389, 369]],
#
#        [[390, 369]],
#
#        [[392, 367]],
#
#        [[393, 367]]], dtype=int32), array([[[357, 365]],
#
#        [[358, 364]],
#
#        [[360, 364]],
#
#        [[361, 365]],
#
#        [[360, 366]],
#
#        [[358, 366]]], dtype=int32), array([[[443, 362]],
#
#        [[444, 363]],
#
#        [[444, 364]],
#
#        [[443, 365]],
#
#        [[443, 366]],
#
#        [[442, 367]],
#
#        [[441, 366]],
#
#        [[441, 364]]], dtype=int32), array([[[381, 363]],
#
#        [[381, 365]]], dtype=int32), array([[[320, 363]]], dtype=int32), array([[[390, 362]],
#
#        [[389, 363]],
#
#        [[390, 364]],
#
#        [[391, 364]],
#
#        [[392, 363]],
#
#        [[393, 364]],
#
#        [[395, 364]],
#
#        [[396, 363]],
#
#        [[397, 363]],
#
#        [[398, 362]],
#
#        [[395, 362]],
#
#        [[394, 363]],
#
#        [[393, 362]],
#
#        [[392, 362]],
#
#        [[391, 363]]], dtype=int32), array([[[416, 361]],
#
#        [[422, 361]]], dtype=int32), array([[[357, 361]],
#
#        [[356, 362]],
#
#        [[356, 363]],
#
#        [[357, 364]],
#
#        [[355, 366]],
#
#        [[356, 367]],
#
#        [[359, 367]],
#
#        [[360, 368]],
#
#        [[367, 368]],
#
#        [[368, 369]],
#
#        [[376, 369]],
#
#        [[377, 368]],
#
#        [[370, 368]],
#
#        [[369, 367]],
#
#        [[363, 367]],
#
#        [[361, 365]],
#
#        [[362, 364]],
#
#        [[367, 364]],
#
#        [[368, 365]],
#
#        [[377, 365]],
#
#        [[377, 364]],
#
#        [[374, 364]],
#
#        [[373, 363]],
#
#        [[366, 363]],
#
#        [[365, 362]],
#
#        [[359, 362]],
#
#        [[358, 361]]], dtype=int32), array([[[424, 360]],
#
#        [[425, 361]],
#
#        [[426, 361]],
#
#        [[426, 360]]], dtype=int32), array([[[445, 359]],
#
#        [[446, 358]],
#
#        [[447, 359]],
#
#        [[446, 360]]], dtype=int32), array([[[432, 358]]], dtype=int32), array([[[447, 357]],
#
#        [[448, 356]],
#
#        [[449, 357]],
#
#        [[448, 358]]], dtype=int32), array([[[398, 356]],
#
#        [[398, 357]],
#
#        [[403, 357]],
#
#        [[402, 356]],
#
#        [[401, 356]],
#
#        [[400, 357]],
#
#        [[399, 356]]], dtype=int32), array([[[382, 354]]], dtype=int32), array([[[372, 353]],
#
#        [[371, 354]],
#
#        [[370, 354]],
#
#        [[368, 356]],
#
#        [[368, 357]],
#
#        [[376, 357]],
#
#        [[377, 358]],
#
#        [[378, 357]],
#
#        [[378, 356]],
#
#        [[377, 356]],
#
#        [[375, 354]],
#
#        [[374, 354]],
#
#        [[373, 353]]], dtype=int32), array([[[360, 353]],
#
#        [[359, 354]],
#
#        [[355, 354]],
#
#        [[355, 355]],
#
#        [[356, 356]],
#
#        [[357, 356]],
#
#        [[358, 357]],
#
#        [[359, 357]],
#
#        [[360, 356]],
#
#        [[362, 356]],
#
#        [[363, 357]],
#
#        [[364, 357]],
#
#        [[365, 356]],
#
#        [[365, 355]],
#
#        [[364, 354]],
#
#        [[363, 354]],
#
#        [[362, 353]]], dtype=int32), array([[[448, 352]],
#
#        [[449, 351]],
#
#        [[450, 352]],
#
#        [[450, 353]],
#
#        [[449, 354]],
#
#        [[448, 353]]], dtype=int32), array([[[433, 352]],
#
#        [[432, 353]],
#
#        [[431, 353]],
#
#        [[429, 355]],
#
#        [[427, 355]],
#
#        [[426, 356]],
#
#        [[424, 356]],
#
#        [[423, 355]],
#
#        [[421, 357]],
#
#        [[419, 357]],
#
#        [[418, 358]],
#
#        [[417, 358]],
#
#        [[416, 359]],
#
#        [[418, 359]],
#
#        [[419, 358]],
#
#        [[424, 358]],
#
#        [[425, 357]],
#
#        [[427, 357]],
#
#        [[428, 356]],
#
#        [[431, 356]],
#
#        [[431, 355]],
#
#        [[432, 354]],
#
#        [[434, 354]],
#
#        [[435, 353]],
#
#        [[435, 352]]], dtype=int32), array([[[396, 352]]], dtype=int32), array([[[418, 351]],
#
#        [[419, 352]],
#
#        [[420, 351]]], dtype=int32), array([[[450, 348]],
#
#        [[451, 349]],
#
#        [[451, 351]],
#
#        [[450, 352]],
#
#        [[448, 350]]], dtype=int32), array([[[358, 348]],
#
#        [[357, 349]],
#
#        [[358, 350]],
#
#        [[365, 350]],
#
#        [[366, 351]],
#
#        [[367, 351]],
#
#        [[366, 351]],
#
#        [[365, 350]],
#
#        [[365, 348]],
#
#        [[364, 349]],
#
#        [[360, 349]],
#
#        [[359, 348]]], dtype=int32), array([[[387, 347]],
#
#        [[386, 348]],
#
#        [[386, 350]],
#
#        [[387, 350]],
#
#        [[388, 349]],
#
#        [[387, 348]]], dtype=int32), array([[[435, 346]],
#
#        [[435, 347]],
#
#        [[434, 348]],
#
#        [[435, 348]]], dtype=int32), array([[[419, 345]]], dtype=int32), array([[[375, 345]],
#
#        [[374, 346]],
#
#        [[374, 350]],
#
#        [[375, 350]],
#
#        [[376, 349]],
#
#        [[377, 349]],
#
#        [[378, 348]],
#
#        [[378, 347]],
#
#        [[377, 346]],
#
#        [[377, 345]]], dtype=int32), array([[[427, 344]],
#
#        [[426, 345]],
#
#        [[426, 346]],
#
#        [[425, 347]],
#
#        [[425, 348]],
#
#        [[424, 349]],
#
#        [[427, 349]],
#
#        [[428, 348]],
#
#        [[428, 347]],
#
#        [[427, 346]]], dtype=int32), array([[[403, 344]],
#
#        [[403, 345]],
#
#        [[402, 346]],
#
#        [[402, 347]],
#
#        [[402, 346]],
#
#        [[403, 345]]], dtype=int32), array([[[346, 344]],
#
#        [[345, 345]],
#
#        [[346, 346]],
#
#        [[346, 347]],
#
#        [[347, 348]],
#
#        [[347, 347]],
#
#        [[346, 346]]], dtype=int32), array([[[367, 343]],
#
#        [[365, 345]],
#
#        [[365, 346]],
#
#        [[366, 346]],
#
#        [[368, 344]],
#
#        [[368, 343]]], dtype=int32), array([[[454, 342]],
#
#        [[455, 341]],
#
#        [[456, 342]],
#
#        [[455, 343]]], dtype=int32), array([[[359, 342]],
#
#        [[359, 343]],
#
#        [[360, 343]],
#
#        [[360, 342]]], dtype=int32), array([[[318, 342]],
#
#        [[319, 341]],
#
#        [[320, 342]],
#
#        [[320, 344]],
#
#        [[321, 343]],
#
#        [[322, 343]],
#
#        [[323, 344]],
#
#        [[323, 351]],
#
#        [[322, 352]],
#
#        [[318, 352]],
#
#        [[318, 353]],
#
#        [[317, 354]],
#
#        [[317, 355]],
#
#        [[318, 356]],
#
#        [[318, 357]],
#
#        [[317, 358]],
#
#        [[314, 358]],
#
#        [[313, 357]],
#
#        [[313, 356]],
#
#        [[315, 354]],
#
#        [[315, 352]],
#
#        [[316, 351]],
#
#        [[316, 350]],
#
#        [[318, 348]]], dtype=int32), array([[[393, 341]],
#
#        [[395, 341]]], dtype=int32), array([[[387, 340]],
#
#        [[387, 345]],
#
#        [[387, 344]],
#
#        [[388, 343]],
#
#        [[389, 343]],
#
#        [[390, 342]],
#
#        [[388, 340]]], dtype=int32), array([[[331, 339]],
#
#        [[331, 340]],
#
#        [[332, 341]],
#
#        [[334, 341]],
#
#        [[335, 340]],
#
#        [[336, 341]],
#
#        [[336, 342]],
#
#        [[335, 343]],
#
#        [[332, 343]],
#
#        [[333, 343]],
#
#        [[334, 344]],
#
#        [[334, 345]],
#
#        [[335, 346]],
#
#        [[335, 348]],
#
#        [[333, 350]],
#
#        [[332, 350]],
#
#        [[332, 352]],
#
#        [[333, 351]],
#
#        [[334, 351]],
#
#        [[336, 353]],
#
#        [[336, 356]],
#
#        [[337, 357]],
#
#        [[338, 357]],
#
#        [[339, 358]],
#
#        [[340, 358]],
#
#        [[341, 359]],
#
#        [[345, 359]],
#
#        [[345, 357]],
#
#        [[343, 357]],
#
#        [[342, 356]],
#
#        [[341, 356]],
#
#        [[339, 354]],
#
#        [[342, 351]],
#
#        [[343, 351]],
#
#        [[343, 349]],
#
#        [[342, 349]],
#
#        [[341, 348]],
#
#        [[341, 347]],
#
#        [[342, 346]],
#
#        [[340, 344]],
#
#        [[340, 342]],
#
#        [[339, 341]],
#
#        [[339, 339]]], dtype=int32), array([[[443, 338]],
#
#        [[443, 339]],
#
#        [[445, 339]],
#
#        [[445, 338]]], dtype=int32), array([[[403, 338]],
#
#        [[402, 339]],
#
#        [[401, 339]],
#
#        [[399, 341]],
#
#        [[399, 342]],
#
#        [[397, 344]],
#
#        [[397, 345]],
#
#        [[394, 348]],
#
#        [[394, 349]],
#
#        [[392, 351]],
#
#        [[392, 352]],
#
#        [[389, 355]],
#
#        [[388, 354]],
#
#        [[389, 355]],
#
#        [[389, 359]],
#
#        [[390, 359]],
#
#        [[390, 358]],
#
#        [[393, 355]],
#
#        [[394, 355]],
#
#        [[394, 354]],
#
#        [[393, 353]],
#
#        [[393, 351]],
#
#        [[395, 349]],
#
#        [[395, 347]],
#
#        [[396, 346]],
#
#        [[397, 346]],
#
#        [[397, 345]],
#
#        [[402, 340]],
#
#        [[404, 340]],
#
#        [[406, 338]]], dtype=int32), array([[[375, 338]],
#
#        [[375, 341]]], dtype=int32), array([[[453, 337]],
#
#        [[454, 336]],
#
#        [[455, 337]],
#
#        [[455, 338]],
#
#        [[454, 339]],
#
#        [[453, 338]]], dtype=int32), array([[[420, 337]],
#
#        [[420, 338]],
#
#        [[421, 338]],
#
#        [[421, 337]]], dtype=int32), array([[[440, 336]],
#
#        [[440, 337]]], dtype=int32), array([[[383, 336]],
#
#        [[382, 337]],
#
#        [[383, 338]]], dtype=int32), array([[[371, 336]],
#
#        [[370, 337]],
#
#        [[370, 338]],
#
#        [[368, 340]],
#
#        [[367, 340]],
#
#        [[368, 340]],
#
#        [[370, 342]],
#
#        [[371, 341]]], dtype=int32), array([[[456, 335]],
#
#        [[457, 334]],
#
#        [[458, 334]],
#
#        [[459, 335]],
#
#        [[458, 336]],
#
#        [[457, 336]]], dtype=int32), array([[[352, 335]],
#
#        [[353, 336]],
#
#        [[353, 338]],
#
#        [[353, 335]]], dtype=int32), array([[[407, 333]],
#
#        [[406, 334]],
#
#        [[395, 334]],
#
#        [[394, 335]],
#
#        [[393, 335]],
#
#        [[392, 334]],
#
#        [[391, 335]],
#
#        [[389, 335]],
#
#        [[390, 335]],
#
#        [[391, 336]],
#
#        [[392, 336]],
#
#        [[393, 335]],
#
#        [[394, 335]],
#
#        [[395, 336]],
#
#        [[396, 335]],
#
#        [[398, 335]],
#
#        [[399, 334]],
#
#        [[400, 335]],
#
#        [[405, 335]],
#
#        [[406, 334]],
#
#        [[407, 334]]], dtype=int32), array([[[382, 333]],
#
#        [[382, 334]],
#
#        [[383, 334]],
#
#        [[383, 333]]], dtype=int32), array([[[459, 331]],
#
#        [[460, 330]],
#
#        [[461, 331]],
#
#        [[461, 332]],
#
#        [[460, 333]],
#
#        [[459, 332]]], dtype=int32), array([[[362, 331]],
#
#        [[363, 330]],
#
#        [[364, 331]],
#
#        [[364, 332]],
#
#        [[363, 333]],
#
#        [[362, 332]]], dtype=int32), array([[[355, 330]],
#
#        [[356, 329]],
#
#        [[357, 329]],
#
#        [[358, 330]],
#
#        [[358, 331]],
#
#        [[357, 332]],
#
#        [[356, 332]],
#
#        [[355, 331]]], dtype=int32), array([[[441, 329]],
#
#        [[440, 330]],
#
#        [[441, 331]]], dtype=int32), array([[[399, 329]],
#
#        [[398, 330]],
#
#        [[391, 330]],
#
#        [[390, 331]],
#
#        [[388, 331]],
#
#        [[388, 332]],
#
#        [[389, 332]],
#
#        [[390, 331]],
#
#        [[395, 331]],
#
#        [[396, 330]],
#
#        [[399, 330]],
#
#        [[400, 331]],
#
#        [[402, 331]],
#
#        [[403, 330]],
#
#        [[406, 330]],
#
#        [[407, 329]]], dtype=int32), array([[[301, 329]],
#
#        [[302, 328]],
#
#        [[303, 329]],
#
#        [[303, 330]],
#
#        [[302, 331]],
#
#        [[301, 330]]], dtype=int32), array([[[358, 327]],
#
#        [[359, 326]],
#
#        [[360, 326]],
#
#        [[361, 327]],
#
#        [[359, 329]],
#
#        [[358, 328]]], dtype=int32), array([[[450, 325]],
#
#        [[449, 326]],
#
#        [[448, 326]],
#
#        [[446, 328]],
#
#        [[449, 328]],
#
#        [[451, 326]],
#
#        [[451, 325]]], dtype=int32), array([[[432, 325]]], dtype=int32), array([[[458, 324]],
#
#        [[458, 325]],
#
#        [[460, 325]],
#
#        [[459, 324]]], dtype=int32), array([[[424, 324]],
#
#        [[423, 325]],
#
#        [[422, 325]],
#
#        [[423, 326]],
#
#        [[425, 326]],
#
#        [[425, 325]]], dtype=int32), array([[[349, 323]],
#
#        [[350, 322]],
#
#        [[351, 323]],
#
#        [[350, 324]]], dtype=int32), array([[[434, 322]],
#
#        [[434, 327]],
#
#        [[433, 328]],
#
#        [[433, 329]],
#
#        [[432, 330]],
#
#        [[431, 330]],
#
#        [[430, 331]],
#
#        [[427, 331]],
#
#        [[426, 332]],
#
#        [[424, 332]],
#
#        [[423, 333]],
#
#        [[419, 333]],
#
#        [[420, 334]],
#
#        [[421, 334]],
#
#        [[422, 333]],
#
#        [[423, 333]],
#
#        [[424, 332]],
#
#        [[431, 332]],
#
#        [[433, 330]],
#
#        [[435, 330]],
#
#        [[435, 326]],
#
#        [[436, 325]],
#
#        [[436, 324]],
#
#        [[437, 323]],
#
#        [[435, 323]]], dtype=int32), array([[[458, 320]],
#
#        [[458, 321]],
#
#        [[459, 320]],
#
#        [[460, 320]]], dtype=int32), array([[[370, 319]],
#
#        [[372, 319]],
#
#        [[374, 321]],
#
#        [[373, 322]],
#
#        [[373, 323]],
#
#        [[372, 324]],
#
#        [[371, 323]],
#
#        [[362, 323]],
#
#        [[361, 322]],
#
#        [[362, 321]],
#
#        [[363, 321]],
#
#        [[364, 320]],
#
#        [[367, 320]],
#
#        [[368, 321]]], dtype=int32), array([[[439, 319]]], dtype=int32), array([[[372, 319]],
#
#        [[373, 318]],
#
#        [[374, 319]],
#
#        [[373, 320]]], dtype=int32), array([[[367, 319]],
#
#        [[368, 318]],
#
#        [[369, 318]],
#
#        [[370, 319]],
#
#        [[369, 320]],
#
#        [[368, 320]]], dtype=int32), array([[[362, 319]],
#
#        [[363, 318]],
#
#        [[364, 318]],
#
#        [[365, 319]],
#
#        [[364, 320]],
#
#        [[363, 320]]], dtype=int32), array([[[303, 318]],
#
#        [[304, 317]],
#
#        [[305, 317]],
#
#        [[306, 318]],
#
#        [[306, 319]],
#
#        [[307, 320]],
#
#        [[307, 324]],
#
#        [[305, 326]],
#
#        [[304, 325]],
#
#        [[304, 324]],
#
#        [[303, 323]]], dtype=int32), array([[[348, 317]],
#
#        [[349, 316]],
#
#        [[350, 316]],
#
#        [[352, 318]],
#
#        [[352, 319]],
#
#        [[350, 321]],
#
#        [[349, 320]],
#
#        [[349, 319]],
#
#        [[348, 318]]], dtype=int32), array([[[424, 315]],
#
#        [[425, 315]]], dtype=int32), array([[[360, 315]],
#
#        [[361, 314]],
#
#        [[362, 315]],
#
#        [[361, 316]]], dtype=int32), array([[[354, 315]],
#
#        [[355, 314]],
#
#        [[356, 315]],
#
#        [[355, 316]]], dtype=int32), array([[[350, 314]],
#
#        [[351, 313]],
#
#        [[352, 314]],
#
#        [[351, 315]]], dtype=int32), array([[[294, 314]],
#
#        [[295, 313]],
#
#        [[296, 314]],
#
#        [[296, 318]],
#
#        [[297, 319]],
#
#        [[297, 320]],
#
#        [[298, 321]],
#
#        [[298, 327]],
#
#        [[299, 328]],
#
#        [[299, 330]],
#
#        [[300, 331]],
#
#        [[300, 332]],
#
#        [[301, 332]],
#
#        [[303, 330]],
#
#        [[304, 331]],
#
#        [[304, 333]],
#
#        [[307, 336]],
#
#        [[307, 337]],
#
#        [[305, 339]],
#
#        [[304, 338]],
#
#        [[304, 336]],
#
#        [[302, 334]],
#
#        [[302, 335]],
#
#        [[301, 336]],
#
#        [[300, 335]],
#
#        [[300, 337]],
#
#        [[303, 340]],
#
#        [[303, 342]],
#
#        [[302, 343]],
#
#        [[303, 344]],
#
#        [[303, 346]],
#
#        [[303, 343]],
#
#        [[304, 342]],
#
#        [[306, 344]],
#
#        [[306, 350]],
#
#        [[307, 350]],
#
#        [[309, 352]],
#
#        [[309, 361]],
#
#        [[308, 362]],
#
#        [[308, 364]],
#
#        [[309, 363]],
#
#        [[310, 363]],
#
#        [[312, 365]],
#
#        [[312, 366]],
#
#        [[310, 368]],
#
#        [[309, 368]],
#
#        [[308, 367]],
#
#        [[309, 368]],
#
#        [[308, 369]],
#
#        [[307, 369]],
#
#        [[307, 372]],
#
#        [[306, 373]],
#
#        [[305, 372]],
#
#        [[305, 364]],
#
#        [[303, 362]],
#
#        [[303, 359]],
#
#        [[304, 358]],
#
#        [[304, 357]],
#
#        [[303, 358]],
#
#        [[302, 357]],
#
#        [[302, 354]],
#
#        [[301, 353]],
#
#        [[301, 352]],
#
#        [[300, 351]],
#
#        [[300, 346]],
#
#        [[299, 345]],
#
#        [[299, 341]],
#
#        [[298, 340]],
#
#        [[298, 336]],
#
#        [[297, 335]],
#
#        [[297, 329]],
#
#        [[296, 328]],
#
#        [[296, 325]],
#
#        [[295, 324]],
#
#        [[295, 320]],
#
#        [[294, 319]]], dtype=int32), array([[[375, 312]],
#
#        [[376, 313]],
#
#        [[377, 312]],
#
#        [[378, 313]],
#
#        [[378, 314]],
#
#        [[376, 316]],
#
#        [[375, 315]],
#
#        [[374, 315]],
#
#        [[373, 314]]], dtype=int32), array([[[368, 312]],
#
#        [[371, 312]],
#
#        [[374, 315]],
#
#        [[373, 316]],
#
#        [[372, 316]],
#
#        [[371, 317]],
#
#        [[369, 315]],
#
#        [[368, 315]],
#
#        [[367, 316]],
#
#        [[366, 316]],
#
#        [[365, 315]]], dtype=int32), array([[[361, 313]],
#
#        [[362, 312]],
#
#        [[364, 312]],
#
#        [[365, 313]],
#
#        [[363, 315]],
#
#        [[362, 315]],
#
#        [[361, 314]]], dtype=int32), array([[[458, 312]],
#
#        [[458, 313]],
#
#        [[460, 313]],
#
#        [[459, 313]]], dtype=int32), array([[[424, 311]],
#
#        [[423, 312]],
#
#        [[424, 312]],
#
#        [[425, 311]]], dtype=int32), array([[[432, 310]],
#
#        [[431, 311]],
#
#        [[430, 311]],
#
#        [[429, 312]],
#
#        [[430, 312]],
#
#        [[431, 311]],
#
#        [[433, 311]]], dtype=int32), array([[[384, 310]],
#
#        [[385, 309]],
#
#        [[386, 309]],
#
#        [[387, 310]],
#
#        [[386, 311]],
#
#        [[385, 311]]], dtype=int32), array([[[416, 309]]], dtype=int32), array([[[348, 308]],
#
#        [[349, 307]],
#
#        [[350, 308]],
#
#        [[349, 309]]], dtype=int32), array([[[373, 307]],
#
#        [[374, 306]],
#
#        [[375, 306]],
#
#        [[376, 307]],
#
#        [[376, 309]],
#
#        [[375, 310]],
#
#        [[372, 310]],
#
#        [[371, 309]],
#
#        [[372, 308]],
#
#        [[373, 308]]], dtype=int32), array([[[361, 307]],
#
#        [[362, 306]],
#
#        [[367, 306]],
#
#        [[368, 307]],
#
#        [[369, 307]],
#
#        [[371, 309]],
#
#        [[370, 310]],
#
#        [[367, 310]],
#
#        [[366, 309]],
#
#        [[365, 309]],
#
#        [[364, 308]],
#
#        [[362, 308]]], dtype=int32), array([[[437, 306]],
#
#        [[437, 307]],
#
#        [[438, 307]],
#
#        [[438, 306]]], dtype=int32), array([[[411, 306]],
#
#        [[411, 307]]], dtype=int32), array([[[302, 306]],
#
#        [[303, 305]],
#
#        [[304, 305]],
#
#        [[305, 306]],
#
#        [[305, 311]],
#
#        [[304, 312]],
#
#        [[302, 310]]], dtype=int32), array([[[293, 306]],
#
#        [[294, 305]],
#
#        [[295, 306]],
#
#        [[295, 310]],
#
#        [[296, 311]],
#
#        [[295, 312]],
#
#        [[294, 312]],
#
#        [[293, 311]]], dtype=int32), array([[[335, 305]],
#
#        [[336, 304]],
#
#        [[339, 304]],
#
#        [[340, 305]],
#
#        [[340, 307]],
#
#        [[341, 308]],
#
#        [[341, 310]],
#
#        [[342, 311]],
#
#        [[342, 313]],
#
#        [[341, 314]],
#
#        [[339, 314]],
#
#        [[335, 310]],
#
#        [[335, 309]],
#
#        [[336, 308]],
#
#        [[336, 306]]], dtype=int32), array([[[390, 303]],
#
#        [[391, 303]],
#
#        [[392, 304]],
#
#        [[390, 306]],
#
#        [[389, 306]],
#
#        [[388, 305]]], dtype=int32), array([[[416, 303]],
#
#        [[416, 304]],
#
#        [[417, 303]]], dtype=int32), array([[[373, 302]],
#
#        [[374, 301]],
#
#        [[375, 302]],
#
#        [[374, 303]]], dtype=int32), array([[[461, 301]],
#
#        [[460, 302]],
#
#        [[461, 303]],
#
#        [[459, 305]],
#
#        [[458, 304]],
#
#        [[458, 303]],
#
#        [[456, 303]],
#
#        [[456, 304]],
#
#        [[458, 304]],
#
#        [[459, 305]],
#
#        [[459, 306]],
#
#        [[458, 307]],
#
#        [[456, 307]],
#
#        [[454, 309]],
#
#        [[452, 309]],
#
#        [[450, 311]],
#
#        [[449, 311]],
#
#        [[451, 311]],
#
#        [[452, 310]],
#
#        [[453, 310]],
#
#        [[455, 312]],
#
#        [[453, 314]],
#
#        [[453, 315]],
#
#        [[454, 316]],
#
#        [[452, 318]],
#
#        [[451, 318]],
#
#        [[449, 320]],
#
#        [[448, 320]],
#
#        [[450, 320]],
#
#        [[451, 319]],
#
#        [[453, 319]],
#
#        [[455, 317]],
#
#        [[456, 317]],
#
#        [[456, 316]],
#
#        [[455, 315]],
#
#        [[455, 311]],
#
#        [[454, 310]],
#
#        [[455, 309]],
#
#        [[457, 309]],
#
#        [[458, 308]],
#
#        [[459, 308]],
#
#        [[461, 310]],
#
#        [[462, 309]],
#
#        [[461, 308]],
#
#        [[461, 306]],
#
#        [[463, 304]],
#
#        [[463, 302]],
#
#        [[462, 301]]], dtype=int32), array([[[399, 301]]], dtype=int32), array([[[384, 301]],
#
#        [[385, 300]],
#
#        [[386, 300]],
#
#        [[387, 301]],
#
#        [[386, 302]],
#
#        [[386, 303]],
#
#        [[385, 304]],
#
#        [[384, 303]]], dtype=int32), array([[[366, 301]],
#
#        [[367, 300]],
#
#        [[368, 300]],
#
#        [[369, 301]],
#
#        [[368, 302]],
#
#        [[367, 302]]], dtype=int32), array([[[342, 300]],
#
#        [[343, 299]],
#
#        [[344, 299]],
#
#        [[345, 300]],
#
#        [[343, 302]],
#
#        [[342, 301]]], dtype=int32), array([[[407, 299]],
#
#        [[406, 300]],
#
#        [[405, 300]],
#
#        [[405, 301]],
#
#        [[406, 301]],
#
#        [[407, 302]],
#
#        [[408, 301]],
#
#        [[410, 301]],
#
#        [[410, 300]],
#
#        [[408, 300]]], dtype=int32), array([[[381, 297]],
#
#        [[382, 296]],
#
#        [[383, 296]],
#
#        [[384, 297]],
#
#        [[384, 300]],
#
#        [[383, 301]],
#
#        [[382, 300]],
#
#        [[382, 299]],
#
#        [[381, 298]]], dtype=int32), array([[[424, 296]],
#
#        [[425, 296]]], dtype=int32), array([[[405, 296]]], dtype=int32), array([[[378, 296]],
#
#        [[379, 295]],
#
#        [[380, 296]],
#
#        [[379, 297]]], dtype=int32), array([[[384, 294]],
#
#        [[385, 293]],
#
#        [[390, 293]],
#
#        [[391, 294]],
#
#        [[390, 295]],
#
#        [[387, 295]],
#
#        [[386, 296]],
#
#        [[385, 296]],
#
#        [[384, 295]]], dtype=int32), array([[[381, 293]],
#
#        [[382, 292]],
#
#        [[383, 293]],
#
#        [[382, 294]]], dtype=int32), array([[[370, 293]],
#
#        [[371, 292]],
#
#        [[372, 293]],
#
#        [[371, 294]]], dtype=int32), array([[[447, 292]],
#
#        [[448, 293]],
#
#        [[448, 292]]], dtype=int32), array([[[440, 291]],
#
#        [[441, 292]]], dtype=int32), array([[[416, 291]]], dtype=int32), array([[[411, 291]],
#
#        [[411, 292]]], dtype=int32), array([[[437, 290]]], dtype=int32), array([[[391, 288]],
#
#        [[393, 288]],
#
#        [[394, 289]],
#
#        [[394, 290]],
#
#        [[393, 291]],
#
#        [[390, 291]],
#
#        [[389, 290]]], dtype=int32), array([[[408, 288]],
#
#        [[409, 287]],
#
#        [[410, 288]],
#
#        [[409, 289]]], dtype=int32), array([[[459, 287]],
#
#        [[458, 288]],
#
#        [[458, 289]],
#
#        [[457, 290]],
#
#        [[457, 291]],
#
#        [[456, 292]],
#
#        [[455, 291]],
#
#        [[455, 290]],
#
#        [[454, 289]],
#
#        [[454, 288]],
#
#        [[452, 288]],
#
#        [[451, 289]],
#
#        [[452, 289]],
#
#        [[454, 291]],
#
#        [[454, 298]],
#
#        [[453, 299]],
#
#        [[453, 301]],
#
#        [[451, 303]],
#
#        [[450, 303]],
#
#        [[450, 304]],
#
#        [[451, 305]],
#
#        [[452, 305]],
#
#        [[454, 303]],
#
#        [[454, 300]],
#
#        [[456, 298]],
#
#        [[457, 298]],
#
#        [[458, 297]],
#
#        [[458, 296]],
#
#        [[459, 295]],
#
#        [[460, 295]],
#
#        [[460, 294]],
#
#        [[459, 294]],
#
#        [[458, 293]],
#
#        [[458, 292]],
#
#        [[459, 291]],
#
#        [[459, 290]],
#
#        [[460, 289]],
#
#        [[460, 287]]], dtype=int32), array([[[407, 287]],
#
#        [[405, 289]],
#
#        [[404, 289]],
#
#        [[404, 290]],
#
#        [[405, 291]],
#
#        [[407, 291]],
#
#        [[410, 288]],
#
#        [[411, 289]],
#
#        [[412, 289]],
#
#        [[412, 288]],
#
#        [[411, 288]],
#
#        [[410, 287]],
#
#        [[409, 287]],
#
#        [[408, 288]]], dtype=int32), array([[[402, 287]],
#
#        [[403, 287]]], dtype=int32), array([[[383, 287]],
#
#        [[384, 286]],
#
#        [[385, 286]],
#
#        [[386, 287]],
#
#        [[385, 288]],
#
#        [[384, 288]]], dtype=int32), array([[[404, 284]],
#
#        [[403, 285]]], dtype=int32), array([[[464, 282]],
#
#        [[462, 284]],
#
#        [[461, 284]],
#
#        [[461, 285]],
#
#        [[463, 285]],
#
#        [[464, 286]],
#
#        [[464, 288]],
#
#        [[462, 290]],
#
#        [[463, 291]],
#
#        [[464, 290]],
#
#        [[469, 290]],
#
#        [[469, 288]],
#
#        [[467, 288]],
#
#        [[466, 287]],
#
#        [[466, 286]],
#
#        [[465, 285]],
#
#        [[465, 284]],
#
#        [[464, 283]]], dtype=int32), array([[[455, 279]],
#
#        [[456, 278]],
#
#        [[457, 278]],
#
#        [[458, 279]],
#
#        [[455, 282]],
#
#        [[454, 281]],
#
#        [[452, 281]],
#
#        [[451, 280]],
#
#        [[452, 279]]], dtype=int32), array([[[439, 279]],
#
#        [[438, 280]],
#
#        [[439, 281]]], dtype=int32), array([[[417, 278]],
#
#        [[418, 277]],
#
#        [[419, 277]],
#
#        [[420, 278]],
#
#        [[418, 280]],
#
#        [[417, 279]]], dtype=int32), array([[[458, 277]],
#
#        [[459, 276]],
#
#        [[460, 276]],
#
#        [[461, 277]],
#
#        [[461, 278]],
#
#        [[460, 279]],
#
#        [[459, 279]],
#
#        [[458, 278]]], dtype=int32), array([[[415, 276]],
#
#        [[416, 275]],
#
#        [[417, 276]],
#
#        [[417, 277]],
#
#        [[416, 278]],
#
#        [[415, 277]]], dtype=int32), array([[[374, 274]],
#
#        [[375, 273]],
#
#        [[376, 274]],
#
#        [[375, 275]]], dtype=int32), array([[[370, 274]],
#
#        [[371, 273]],
#
#        [[373, 273]],
#
#        [[374, 274]],
#
#        [[374, 275]],
#
#        [[375, 276]],
#
#        [[375, 277]],
#
#        [[374, 278]],
#
#        [[372, 278]],
#
#        [[371, 277]],
#
#        [[371, 275]]], dtype=int32), array([[[367, 274]],
#
#        [[368, 273]],
#
#        [[369, 274]],
#
#        [[368, 275]]], dtype=int32), array([[[368, 273]],
#
#        [[369, 272]],
#
#        [[370, 272]],
#
#        [[371, 273]],
#
#        [[370, 274]],
#
#        [[369, 274]]], dtype=int32), array([[[433, 271]],
#
#        [[434, 271]],
#
#        [[436, 273]],
#
#        [[436, 274]],
#
#        [[435, 275]],
#
#        [[432, 275]],
#
#        [[431, 274]],
#
#        [[431, 273]]], dtype=int32), array([[[375, 272]],
#
#        [[376, 271]],
#
#        [[377, 272]],
#
#        [[376, 273]]], dtype=int32), array([[[438, 271]],
#
#        [[439, 270]],
#
#        [[440, 270]],
#
#        [[441, 271]],
#
#        [[440, 272]],
#
#        [[439, 272]]], dtype=int32), array([[[427, 270]],
#
#        [[428, 271]],
#
#        [[428, 272]],
#
#        [[427, 273]],
#
#        [[426, 273]],
#
#        [[425, 272]]], dtype=int32), array([[[363, 269]],
#
#        [[364, 268]],
#
#        [[365, 269]],
#
#        [[364, 270]]], dtype=int32), array([[[442, 267]],
#
#        [[443, 266]],
#
#        [[444, 266]],
#
#        [[445, 267]],
#
#        [[445, 268]],
#
#        [[446, 269]],
#
#        [[445, 270]],
#
#        [[444, 270]],
#
#        [[442, 268]]], dtype=int32), array([[[465, 264]],
#
#        [[466, 263]],
#
#        [[467, 264]],
#
#        ...,
#
#        [[466, 271]],
#
#        [[466, 266]],
#
#        [[465, 265]]], dtype=int32), array([[[465, 262]],
#
#        [[466, 261]],
#
#        [[467, 262]],
#
#        [[466, 263]]], dtype=int32), array([[[472, 256]],
#
#        [[473, 255]],
#
#        [[474, 255]],
#
#        [[476, 257]],
#
#        [[476, 258]],
#
#        [[470, 264]],
#
#        [[468, 262]],
#
#        [[468, 261]],
#
#        [[467, 260]],
#
#        [[469, 258]],
#
#        [[472, 258]]], dtype=int32), array([[[471, 253]],
#
#        [[472, 254]],
#
#        [[472, 256]],
#
#        [[471, 257]],
#
#        [[469, 257]],
#
#        [[468, 256]]], dtype=int32), array([[[388, 242]],
#
#        [[391, 242]],
#
#        [[392, 243]],
#
#        [[387, 248]],
#
#        [[385, 248]],
#
#        [[384, 247]],
#
#        [[384, 246]]], dtype=int32), array([[[397, 240]],
#
#        [[398, 239]],
#
#        [[400, 241]],
#
#        [[400, 242]],
#
#        [[399, 243]],
#
#        [[397, 241]]], dtype=int32), array([[[374, 239]],
#
#        [[375, 238]],
#
#        [[377, 240]],
#
#        [[377, 243]],
#
#        [[375, 245]],
#
#        [[374, 244]],
#
#        [[373, 244]],
#
#        [[372, 243]],
#
#        [[372, 240]],
#
#        [[373, 239]]], dtype=int32), array([[[474, 236]],
#
#        [[476, 238]],
#
#        [[476, 242]],
#
#        [[475, 243]],
#
#        [[474, 243]],
#
#        [[473, 242]],
#
#        [[473, 241]],
#
#        [[472, 240]],
#
#        [[472, 238]]], dtype=int32), array([[[407, 235]],
#
#        [[408, 234]],
#
#        [[409, 235]],
#
#        [[408, 236]]], dtype=int32), array([[[423, 234]],
#
#        [[424, 233]],
#
#        [[425, 234]],
#
#        [[424, 235]]], dtype=int32), array([[[392, 233]]], dtype=int32), array([[[355, 232]],
#
#        [[356, 231]],
#
#        [[357, 231]],
#
#        [[358, 232]],
#
#        [[356, 234]],
#
#        [[355, 233]]], dtype=int32), array([[[375, 231]]], dtype=int32), array([[[430, 230]],
#
#        [[431, 229]],
#
#        [[432, 229]],
#
#        [[433, 230]],
#
#        [[433, 231]],
#
#        [[431, 233]],
#
#        [[430, 232]]], dtype=int32), array([[[400, 227]],
#
#        [[398, 229]],
#
#        [[397, 229]],
#
#        [[397, 230]],
#
#        [[399, 230]],
#
#        [[399, 229]],
#
#        [[400, 228]],
#
#        [[401, 229]],
#
#        [[402, 229]],
#
#        [[402, 228]],
#
#        [[401, 227]]], dtype=int32), array([[[391, 227]],
#
#        [[390, 228]],
#
#        [[387, 228]],
#
#        [[387, 230]],
#
#        [[391, 230]],
#
#        [[392, 229]],
#
#        [[395, 229]],
#
#        [[395, 227]]], dtype=int32), array([[[437, 225]],
#
#        [[438, 226]],
#
#        [[438, 227]],
#
#        [[437, 228]],
#
#        [[436, 228]],
#
#        [[435, 227]]], dtype=int32), array([[[405, 226]],
#
#        [[406, 226]]], dtype=int32), array([[[363, 226]],
#
#        [[364, 225]],
#
#        [[365, 226]],
#
#        [[364, 227]]], dtype=int32), array([[[414, 225]],
#
#        [[415, 225]]], dtype=int32), array([[[464, 224]],
#
#        [[465, 223]],
#
#        [[466, 223]],
#
#        [[467, 224]],
#
#        [[466, 225]],
#
#        [[465, 225]]], dtype=int32), array([[[419, 224]],
#
#        [[421, 224]]], dtype=int32), array([[[408, 224]]], dtype=int32), array([[[399, 224]],
#
#        [[402, 224]]], dtype=int32), array([[[411, 223]]], dtype=int32), array([[[463, 219]],
#
#        [[464, 218]],
#
#        [[465, 219]],
#
#        [[465, 220]],
#
#        [[464, 221]],
#
#        [[463, 220]]], dtype=int32), array([[[459, 216]],
#
#        [[461, 218]],
#
#        [[461, 220]],
#
#        [[460, 221]],
#
#        [[458, 221]],
#
#        [[457, 220]],
#
#        [[457, 218]]], dtype=int32), array([[[300, 217]],
#
#        [[301, 216]],
#
#        [[302, 217]],
#
#        [[302, 218]],
#
#        [[301, 219]],
#
#        [[300, 218]]], dtype=int32), array([[[399, 215]],
#
#        [[400, 214]],
#
#        [[401, 215]],
#
#        [[400, 216]]], dtype=int32), array([[[391, 215]],
#
#        [[392, 214]],
#
#        [[395, 214]],
#
#        [[396, 215]],
#
#        [[397, 214]],
#
#        [[398, 214]],
#
#        [[399, 215]],
#
#        [[397, 217]],
#
#        [[392, 217]],
#
#        [[391, 216]]], dtype=int32), array([[[386, 215]],
#
#        [[387, 214]],
#
#        [[388, 215]],
#
#        [[387, 216]]], dtype=int32), array([[[301, 215]],
#
#        [[302, 214]],
#
#        [[303, 215]],
#
#        [[302, 216]]], dtype=int32), array([[[302, 214]],
#
#        [[303, 213]],
#
#        [[304, 214]],
#
#        [[303, 215]]], dtype=int32), array([[[454, 212]],
#
#        [[455, 211]],
#
#        [[457, 211]],
#
#        [[458, 212]],
#
#        [[458, 213]],
#
#        [[456, 215]],
#
#        [[455, 215]],
#
#        [[454, 214]]], dtype=int32), array([[[432, 212]]], dtype=int32), array([[[369, 212]],
#
#        [[370, 211]],
#
#        [[371, 211]],
#
#        [[372, 212]],
#
#        [[372, 213]],
#
#        [[371, 214]]], dtype=int32), array([[[378, 211]],
#
#        [[379, 210]],
#
#        [[380, 211]],
#
#        [[380, 212]],
#
#        [[381, 212]],
#
#        [[382, 213]],
#
#        [[383, 213]],
#
#        [[385, 215]],
#
#        [[384, 216]],
#
#        [[383, 216]],
#
#        [[382, 215]],
#
#        [[381, 216]],
#
#        [[380, 216]],
#
#        [[378, 214]]], dtype=int32), array([[[365, 209]],
#
#        [[366, 208]],
#
#        [[369, 208]],
#
#        [[370, 209]],
#
#        [[369, 210]],
#
#        [[368, 210]],
#
#        [[366, 212]],
#
#        [[365, 211]]], dtype=int32), array([[[417, 208]],
#
#        [[418, 207]],
#
#        [[419, 208]],
#
#        [[418, 209]]], dtype=int32), array([[[375, 206]],
#
#        [[376, 205]],
#
#        [[377, 206]],
#
#        [[376, 207]]], dtype=int32), array([[[364, 206]],
#
#        [[365, 205]],
#
#        [[366, 206]],
#
#        [[366, 207]],
#
#        [[365, 208]],
#
#        [[364, 207]]], dtype=int32), array([[[360, 205]],
#
#        [[361, 206]],
#
#        [[361, 207]],
#
#        [[362, 208]],
#
#        [[362, 212]],
#
#        [[361, 213]],
#
#        [[360, 212]],
#
#        [[360, 209]],
#
#        [[358, 209]],
#
#        [[357, 208]]], dtype=int32), array([[[338, 206]],
#
#        [[339, 205]],
#
#        [[340, 206]],
#
#        [[340, 207]],
#
#        [[339, 208]],
#
#        [[338, 207]]], dtype=int32), array([[[431, 205]],
#
#        [[432, 204]],
#
#        [[433, 205]],
#
#        [[432, 206]]], dtype=int32), array([[[349, 205]],
#
#        [[350, 204]],
#
#        [[351, 205]],
#
#        [[351, 207]],
#
#        [[350, 208]],
#
#        [[349, 207]]], dtype=int32), array([[[355, 204]],
#
#        [[356, 203]],
#
#        [[357, 204]],
#
#        [[357, 206]],
#
#        [[358, 207]],
#
#        [[357, 208]],
#
#        [[354, 208]],
#
#        [[353, 207]],
#
#        [[353, 206]],
#
#        [[354, 205]],
#
#        [[355, 205]]], dtype=int32), array([[[435, 203]],
#
#        [[436, 202]],
#
#        [[437, 202]],
#
#        [[438, 203]],
#
#        [[436, 205]],
#
#        [[434, 205]],
#
#        [[433, 204]],
#
#        [[434, 203]]], dtype=int32), array([[[344, 202]],
#
#        [[345, 201]],
#
#        [[346, 202]],
#
#        [[345, 203]]], dtype=int32), array([[[329, 202]],
#
#        [[330, 201]],
#
#        [[331, 202]],
#
#        [[330, 203]]], dtype=int32), array([[[356, 201]],
#
#        [[357, 200]],
#
#        [[358, 201]],
#
#        [[357, 202]]], dtype=int32), array([[[348, 200]],
#
#        [[349, 201]],
#
#        [[349, 203]],
#
#        [[350, 204]],
#
#        [[349, 205]],
#
#        [[347, 205]],
#
#        [[346, 204]],
#
#        [[346, 202]]], dtype=int32), array([[[406, 200]],
#
#        [[407, 199]],
#
#        [[409, 201]],
#
#        [[408, 202]],
#
#        [[407, 202]],
#
#        [[406, 201]]], dtype=int32), array([[[401, 199]],
#
#        [[402, 198]],
#
#        [[403, 199]],
#
#        [[403, 200]],
#
#        [[402, 201]],
#
#        [[401, 200]]], dtype=int32), array([[[343, 199]],
#
#        [[344, 198]],
#
#        [[345, 198]],
#
#        [[346, 199]],
#
#        [[346, 200]],
#
#        [[345, 201]],
#
#        [[344, 201]],
#
#        [[343, 200]]], dtype=int32), array([[[335, 199]],
#
#        [[336, 198]],
#
#        [[337, 199]],
#
#        [[336, 200]]], dtype=int32), array([[[327, 199]],
#
#        [[328, 198]],
#
#        [[329, 199]],
#
#        [[328, 200]]], dtype=int32), array([[[443, 197]],
#
#        [[444, 196]],
#
#        [[445, 197]],
#
#        [[444, 198]]], dtype=int32), array([[[414, 197]],
#
#        [[415, 196]],
#
#        [[416, 196]],
#
#        [[417, 197]],
#
#        [[416, 198]],
#
#        [[415, 198]]], dtype=int32), array([[[410, 197]],
#
#        [[411, 196]],
#
#        [[412, 197]],
#
#        [[412, 198]],
#
#        [[411, 199]],
#
#        [[410, 198]]], dtype=int32), array([[[340, 196]],
#
#        [[341, 197]],
#
#        [[341, 199]],
#
#        [[340, 200]],
#
#        [[338, 198]]], dtype=int32), array([[[319, 197]],
#
#        [[320, 196]],
#
#        [[321, 196]],
#
#        [[322, 197]],
#
#        [[322, 198]],
#
#        [[328, 204]],
#
#        [[328, 203]],
#
#        [[329, 202]],
#
#        [[330, 203]],
#
#        [[330, 204]],
#
#        [[331, 205]],
#
#        [[335, 205]],
#
#        [[336, 206]],
#
#        [[336, 207]],
#
#        [[338, 209]],
#
#        [[339, 209]],
#
#        [[340, 210]],
#
#        [[342, 210]],
#
#        [[343, 211]],
#
#        [[344, 211]],
#
#        [[345, 212]],
#
#        [[346, 212]],
#
#        [[347, 213]],
#
#        [[350, 213]],
#
#        [[351, 214]],
#
#        [[355, 214]],
#
#        [[356, 215]],
#
#        [[360, 215]],
#
#        [[361, 216]],
#
#        [[369, 216]],
#
#        [[370, 217]],
#
#        [[372, 217]],
#
#        [[373, 216]],
#
#        [[375, 216]],
#
#        [[376, 217]],
#
#        [[411, 217]],
#
#        [[412, 216]],
#
#        [[419, 216]],
#
#        [[420, 215]],
#
#        [[423, 215]],
#
#        [[424, 214]],
#
#        [[427, 214]],
#
#        [[427, 213]],
#
#        [[426, 214]],
#
#        [[420, 214]],
#
#        [[419, 215]],
#
#        [[414, 215]],
#
#        [[413, 216]],
#
#        [[405, 216]],
#
#        [[404, 215]],
#
#        [[405, 214]],
#
#        [[408, 214]],
#
#        [[409, 213]],
#
#        [[415, 213]],
#
#        [[416, 212]],
#
#        [[420, 212]],
#
#        [[421, 211]],
#
#        [[424, 211]],
#
#        [[425, 210]],
#
#        [[429, 210]],
#
#        [[430, 209]],
#
#        [[433, 209]],
#
#        [[434, 208]],
#
#        [[435, 208]],
#
#        [[436, 207]],
#
#        [[437, 207]],
#
#        [[438, 206]],
#
#        [[440, 206]],
#
#        [[443, 203]],
#
#        [[444, 203]],
#
#        [[446, 205]],
#
#        [[447, 205]],
#
#        [[447, 204]],
#
#        [[450, 201]],
#
#        [[452, 203]],
#
#        [[453, 203]],
#
#        [[454, 204]],
#
#        [[454, 205]],
#
#        [[455, 206]],
#
#        [[454, 207]],
#
#        [[456, 207]],
#
#        [[457, 206]],
#
#        [[458, 206]],
#
#        [[459, 207]],
#
#        [[458, 208]],
#
#        [[458, 209]],
#
#        [[457, 210]],
#
#        [[452, 210]],
#
#        [[451, 211]],
#
#        [[451, 212]],
#
#        [[450, 213]],
#
#        [[449, 212]],
#
#        [[447, 212]],
#
#        [[447, 213]],
#
#        [[448, 214]],
#
#        [[447, 215]],
#
#        [[446, 215]],
#
#        [[445, 216]],
#
#        [[440, 216]],
#
#        [[439, 217]],
#
#        [[437, 217]],
#
#        [[436, 218]],
#
#        [[435, 218]],
#
#        [[433, 220]],
#
#        [[432, 220]],
#
#        [[431, 221]],
#
#        [[430, 221]],
#
#        [[429, 222]],
#
#        [[427, 222]],
#
#        [[426, 221]],
#
#        [[424, 221]],
#
#        [[423, 222]],
#
#        [[421, 222]],
#
#        [[430, 222]],
#
#        [[431, 223]],
#
#        [[434, 223]],
#
#        [[435, 224]],
#
#        [[432, 227]],
#
#        [[429, 227]],
#
#        [[429, 229]],
#
#        [[428, 230]],
#
#        [[421, 230]],
#
#        [[420, 231]],
#
#        [[415, 231]],
#
#        [[414, 232]],
#
#        [[411, 232]],
#
#        [[410, 233]],
#
#        [[409, 233]],
#
#        [[408, 232]],
#
#        [[407, 233]],
#
#        [[403, 233]],
#
#        [[402, 234]],
#
#        [[401, 234]],
#
#        [[400, 233]],
#
#        [[395, 233]],
#
#        [[391, 237]],
#
#        [[390, 237]],
#
#        [[389, 236]],
#
#        [[390, 235]],
#
#        [[390, 234]],
#
#        [[389, 233]],
#
#        [[388, 233]],
#
#        [[387, 232]],
#
#        [[386, 232]],
#
#        [[385, 233]],
#
#        [[382, 233]],
#
#        [[382, 234]],
#
#        [[383, 235]],
#
#        [[383, 236]],
#
#        [[389, 236]],
#
#        [[390, 237]],
#
#        [[387, 240]],
#
#        [[386, 240]],
#
#        [[385, 241]],
#
#        [[384, 241]],
#
#        [[383, 242]],
#
#        [[383, 243]],
#
#        [[381, 245]],
#
#        [[379, 243]],
#
#        [[379, 233]],
#
#        [[378, 232]],
#
#        [[378, 230]],
#
#        [[380, 228]],
#
#        [[381, 228]],
#
#        [[381, 227]],
#
#        [[380, 227]],
#
#        [[378, 225]],
#
#        [[378, 224]],
#
#        [[375, 224]],
#
#        [[376, 225]],
#
#        [[377, 224]],
#
#        [[378, 225]],
#
#        [[378, 227]],
#
#        [[377, 228]],
#
#        [[377, 236]],
#
#        [[376, 237]],
#
#        [[371, 237]],
#
#        [[371, 241]],
#
#        [[370, 242]],
#
#        [[369, 242]],
#
#        [[367, 240]],
#
#        [[367, 239]],
#
#        [[366, 238]],
#
#        [[366, 237]],
#
#        [[365, 236]],
#
#        [[365, 233]],
#
#        [[366, 232]],
#
#        [[365, 231]],
#
#        [[364, 232]],
#
#        [[363, 232]],
#
#        [[362, 231]],
#
#        [[362, 230]],
#
#        [[360, 230]],
#
#        [[359, 231]],
#
#        [[358, 231]],
#
#        [[357, 230]],
#
#        [[357, 229]],
#
#        [[358, 228]],
#
#        [[360, 228]],
#
#        [[362, 226]],
#
#        [[363, 226]],
#
#        [[364, 227]],
#
#        [[365, 227]],
#
#        [[367, 225]],
#
#        [[370, 225]],
#
#        [[371, 224]],
#
#        [[370, 223]],
#
#        [[368, 223]],
#
#        [[367, 222]],
#
#        [[356, 222]],
#
#        [[355, 223]],
#
#        [[354, 222]],
#
#        [[354, 221]],
#
#        [[353, 220]],
#
#        [[353, 219]],
#
#        [[351, 219]],
#
#        [[350, 218]],
#
#        [[347, 218]],
#
#        [[346, 217]],
#
#        [[343, 217]],
#
#        [[342, 216]],
#
#        [[340, 216]],
#
#        [[339, 215]],
#
#        [[335, 215]],
#
#        [[334, 214]],
#
#        [[332, 214]],
#
#        [[331, 213]],
#
#        [[329, 213]],
#
#        [[327, 211]],
#
#        [[326, 211]],
#
#        [[325, 210]],
#
#        [[324, 210]],
#
#        [[323, 209]],
#
#        [[322, 209]],
#
#        [[321, 208]],
#
#        [[320, 209]],
#
#        [[315, 209]],
#
#        [[314, 210]],
#
#        [[313, 210]],
#
#        [[312, 211]],
#
#        [[312, 214]],
#
#        [[309, 217]],
#
#        [[309, 218]],
#
#        [[307, 220]],
#
#        [[306, 220]],
#
#        [[305, 219]],
#
#        [[305, 216]],
#
#        [[306, 215]],
#
#        [[307, 215]],
#
#        [[306, 214]],
#
#        [[305, 214]],
#
#        [[303, 212]],
#
#        [[303, 211]],
#
#        [[307, 207]],
#
#        [[307, 206]],
#
#        [[312, 201]],
#
#        [[313, 201]],
#
#        [[316, 198]],
#
#        [[317, 198]],
#
#        [[318, 197]]], dtype=int32), array([[[446, 194]],
#
#        [[447, 193]],
#
#        [[448, 194]],
#
#        [[448, 195]],
#
#        [[447, 196]],
#
#        [[446, 195]]], dtype=int32), array([[[417, 194]],
#
#        [[418, 193]],
#
#        [[419, 194]],
#
#        [[418, 195]]], dtype=int32), array([[[367, 194]],
#
#        [[368, 193]],
#
#        [[369, 194]],
#
# ...
#
#        [[419, 113]],
#
#        [[420, 112]],
#
#        [[421, 113]],
#
#        [[421, 114]],
#
#        [[420, 115]],
#
#        [[420, 117]],
#
#        [[419, 118]],
#
#        [[418, 117]],
#
#        [[418, 116]],
#
#        [[417, 115]],
#
#        [[416, 115]],
#
#        [[415, 116]],
#
#        [[414, 116]],
#
#        [[411, 119]],
#
#        [[410, 119]],
#
#        [[409, 118]],
#
#        [[410, 117]],
#
#        [[410, 116]],
#
#        [[411, 115]],
#
#        [[411, 114]]], dtype=int32), array([[[419, 110]],
#
#        [[420, 109]],
#
#        [[421, 110]],
#
#        [[421, 111]],
#
#        [[420, 112]],
#
#        [[419, 111]]], dtype=int32), array([[[415, 109]],
#
#        [[416, 108]],
#
#        [[417, 109]],
#
#        [[416, 110]]], dtype=int32), array([[[335, 105]],
#
#        [[335, 106]],
#
#        [[336, 107]],
#
#        [[337, 106]],
#
#        [[336, 105]]], dtype=int32), array([[[341,  96]],
#
#        [[342,  95]],
#
#        [[343,  96]],
#
#        [[343,  97]],
#
#        [[342,  98]],
#
#        [[341,  97]]], dtype=int32), array([[[411,  93]],
#
#        [[412,  92]],
#
#        [[413,  93]],
#
#        [[412,  94]]], dtype=int32), array([[[343,  92]],
#
#        [[344,  91]],
#
#        [[345,  91]],
#
#        [[346,  92]],
#
#        [[346,  94]],
#
#        [[345,  95]],
#
#        [[344,  95]],
#
#        [[343,  94]]], dtype=int32), array([[[344,  88]],
#
#        [[345,  87]],
#
#        [[346,  87]],
#
#        [[347,  88]],
#
#        [[347,  90]],
#
#        [[346,  91]],
#
#        [[345,  91]],
#
#        [[344,  90]]], dtype=int32), array([[[346,  87]],
#
#        [[347,  86]],
#
#        [[348,  87]],
#
#        [[347,  88]]], dtype=int32), array([[[355,  39]],
#
#        [[356,  38]],
#
#        [[357,  39]],
#
#        [[356,  40]]], dtype=int32), array([[[371,  29]],
#
#        [[372,  30]],
#
#        [[372,  44]],
#
#        [[373,  45]],
#
#        [[373,  47]],
#
#        [[372,  48]],
#
#        [[373,  49]],
#
#        [[373,  55]],
#
#        [[374,  56]],
#
#        [[374,  59]],
#
#        [[373,  60]],
#
#        [[373,  66]],
#
#        [[372,  67]],
#
#        [[372,  71]],
#
#        [[371,  72]],
#
#        [[370,  71]],
#
#        [[370,  66]],
#
#        [[369,  65]],
#
#        [[369,  61]],
#
#        [[367,  59]],
#
#        [[367,  56]],
#
#        [[368,  55]],
#
#        [[368,  48]],
#
#        [[367,  47]],
#
#        [[367,  45]],
#
#        [[368,  44]],
#
#        [[369,  45]],
#
#        [[369,  44]],
#
#        [[368,  43]],
#
#        [[368,  34]],
#
#        [[369,  33]],
#
#        [[369,  31]]], dtype=int32), array([[[358,  28]],
#
#        [[359,  29]],
#
#        [[359,  30]],
#
#        [[358,  31]],
#
#        [[358,  33]],
#
#        [[357,  34]],
#
#        [[357,  35]],
#
#        [[356,  36]],
#
#        [[356,  37]],
#
#        [[354,  39]],
#
#        [[354,  41]],
#
#        [[353,  42]],
#
#        [[353,  43]],
#
#        [[354,  44]],
#
#        [[354,  45]],
#
#        [[352,  47]],
#
#        [[352,  50]],
#
#        [[351,  51]],
#
#        [[351,  53]],
#
#        [[350,  54]],
#
#        [[350,  61]],
#
#        [[349,  62]],
#
#        [[349,  63]],
#
#        [[348,  64]],
#
#        [[347,  64]],
#
#        [[347,  66]],
#
#        [[345,  68]],
#
#        [[344,  68]],
#
#        [[343,  69]],
#
#        [[342,  69]],
#
#        [[343,  70]],
#
#        [[344,  70]],
#
#        [[345,  71]],
#
#        [[344,  72]],
#
#        [[347,  75]],
#
#        [[347,  76]],
#
#        [[345,  78]],
#
#        [[344,  78]],
#
#        [[344,  82]],
#
#        [[343,  83]],
#
#        [[342,  82]],
#
#        [[342,  85]],
#
#        [[343,  86]],
#
#        [[343,  87]],
#
#        [[344,  88]],
#
#        [[344,  90]],
#
#        [[342,  92]],
#
#        [[341,  92]],
#
#        [[340,  93]],
#
#        [[340,  95]],
#
#        [[339,  96]],
#
#        [[339,  97]],
#
#        [[340,  98]],
#
#        [[338, 100]],
#
#        [[336,  98]],
#
#        [[336,  97]],
#
#        [[337,  96]],
#
#        [[337,  88]],
#
#        [[337,  89]],
#
#        [[336,  90]],
#
#        [[336,  92]],
#
#        [[335,  93]],
#
#        [[335, 102]],
#
#        [[335, 101]],
#
#        [[336, 100]],
#
#        [[339, 100]],
#
#        [[341,  98]],
#
#        [[342,  99]],
#
#        [[342, 101]],
#
#        [[341, 102]],
#
#        [[340, 102]],
#
#        [[339, 103]],
#
#        [[339, 105]],
#
#        [[340, 105]],
#
#        [[341, 106]],
#
#        [[341, 109]],
#
#        [[340, 110]],
#
#        [[340, 112]],
#
#        [[342, 112]],
#
#        [[343, 113]],
#
#        [[343, 119]],
#
#        [[344, 120]],
#
#        [[344, 121]],
#
#        [[345, 122]],
#
#        [[345, 123]],
#
#        [[344, 124]],
#
#        [[343, 123]],
#
#        [[344, 124]],
#
#        [[344, 125]],
#
#        [[346, 127]],
#
#        [[346, 128]],
#
#        [[347, 129]],
#
#        [[347, 130]],
#
#        [[348, 130]],
#
#        [[350, 132]],
#
#        [[350, 133]],
#
#        [[351, 133]],
#
#        [[355, 137]],
#
#        [[356, 137]],
#
#        [[358, 139]],
#
#        [[358, 140]],
#
#        [[360, 140]],
#
#        [[362, 138]],
#
#        [[363, 138]],
#
#        [[364, 139]],
#
#        [[366, 139]],
#
#        [[366, 136]],
#
#        [[365, 135]],
#
#        [[365, 134]],
#
#        [[364, 133]],
#
#        [[364, 130]],
#
#        [[362, 130]],
#
#        [[361, 129]],
#
#        [[361, 128]],
#
#        [[362, 127]],
#
#        [[363, 127]],
#
#        [[364, 128]],
#
#        [[365, 128]],
#
#        [[365, 127]],
#
#        [[368, 124]],
#
#        [[370, 124]],
#
#        [[370, 123]],
#
#        [[372, 121]],
#
#        [[374, 123]],
#
#        [[377, 123]],
#
#        [[377, 121]],
#
#        [[378, 120]],
#
#        [[380, 120]],
#
#        [[381, 121]],
#
#        [[383, 121]],
#
#        [[384, 122]],
#
#        [[385, 122]],
#
#        [[386, 123]],
#
#        [[388, 123]],
#
#        [[389, 124]],
#
#        [[390, 124]],
#
#        [[391, 125]],
#
#        [[395, 125]],
#
#        [[396, 126]],
#
#        [[400, 126]],
#
#        [[401, 127]],
#
#        [[400, 128]],
#
#        [[399, 128]],
#
#        [[398, 129]],
#
#        [[390, 129]],
#
#        [[388, 127]],
#
#        [[385, 127]],
#
#        [[384, 126]],
#
#        [[382, 126]],
#
#        [[382, 127]],
#
#        [[381, 128]],
#
#        [[379, 128]],
#
#        [[379, 130]],
#
#        [[378, 131]],
#
#        [[378, 133]],
#
#        [[380, 133]],
#
#        [[381, 134]],
#
#        [[381, 136]],
#
#        [[384, 136]],
#
#        [[385, 137]],
#
#        [[384, 138]],
#
#        [[384, 139]],
#
#        [[383, 140]],
#
#        [[380, 140]],
#
#        [[379, 141]],
#
#        [[378, 141]],
#
#        [[378, 142]],
#
#        [[379, 143]],
#
#        [[385, 143]],
#
#        [[386, 144]],
#
#        [[389, 144]],
#
#        [[391, 146]],
#
#        [[393, 146]],
#
#        [[395, 148]],
#
#        [[397, 148]],
#
#        [[398, 149]],
#
#        [[399, 149]],
#
#        [[401, 151]],
#
#        [[402, 151]],
#
#        [[403, 152]],
#
#        [[402, 153]],
#
#        [[399, 153]],
#
#        [[398, 152]],
#
#        [[396, 152]],
#
#        [[395, 153]],
#
#        [[394, 152]],
#
#        [[394, 151]],
#
#        [[391, 151]],
#
#        [[392, 152]],
#
#        [[391, 153]],
#
#        [[391, 154]],
#
#        [[390, 155]],
#
#        [[389, 155]],
#
#        [[386, 158]],
#
#        [[386, 159]],
#
#        [[385, 160]],
#
#        [[383, 160]],
#
#        [[383, 161]],
#
#        [[382, 162]],
#
#        [[381, 162]],
#
#        [[380, 161]],
#
#        [[380, 162]],
#
#        [[378, 164]],
#
#        [[376, 164]],
#
#        [[376, 166]],
#
#        [[379, 169]],
#
#        [[379, 170]],
#
#        [[380, 171]],
#
#        [[377, 174]],
#
#        [[376, 174]],
#
#        [[375, 173]],
#
#        [[373, 173]],
#
#        [[372, 172]],
#
#        [[373, 171]],
#
#        [[373, 170]],
#
#        [[375, 168]],
#
#        [[374, 167]],
#
#        [[374, 166]],
#
#        [[373, 166]],
#
#        [[372, 165]],
#
#        [[372, 164]],
#
#        [[371, 163]],
#
#        [[371, 161]],
#
#        [[370, 160]],
#
#        [[369, 160]],
#
#        [[365, 156]],
#
#        [[365, 155]],
#
#        [[364, 154]],
#
#        [[364, 151]],
#
#        [[365, 150]],
#
#        [[367, 150]],
#
#        [[367, 149]],
#
#        [[365, 147]],
#
#        [[365, 148]],
#
#        [[364, 149]],
#
#        [[361, 146]],
#
#        [[359, 146]],
#
#        [[358, 145]],
#
#        [[358, 144]],
#
#        [[355, 141]],
#
#        [[355, 140]],
#
#        [[352, 140]],
#
#        [[351, 141]],
#
#        [[350, 140]],
#
#        [[350, 139]],
#
#        [[351, 138]],
#
#        [[350, 138]],
#
#        [[347, 135]],
#
#        [[347, 134]],
#
#        [[344, 131]],
#
#        [[344, 130]],
#
#        [[342, 128]],
#
#        [[342, 127]],
#
#        [[339, 124]],
#
#        [[339, 123]],
#
#        [[338, 122]],
#
#        [[338, 121]],
#
#        [[336, 119]],
#
#        [[336, 117]],
#
#        [[335, 116]],
#
#        [[335, 115]],
#
#        [[334, 114]],
#
#        [[334, 113]],
#
#        [[333, 112]],
#
#        [[333, 109]],
#
#        [[332, 108]],
#
#        [[332,  94]],
#
#        [[333,  93]],
#
#        [[333,  90]],
#
#        [[334,  89]],
#
#        [[334,  83]],
#
#        [[335,  82]],
#
#        [[335,  80]],
#
#        [[336,  79]],
#
#        [[336,  76]],
#
#        [[337,  75]],
#
#        [[337,  73]],
#
#        [[338,  72]],
#
#        [[338,  69]],
#
#        [[339,  68]],
#
#        [[339,  66]],
#
#        [[340,  65]],
#
#        [[340,  63]],
#
#        [[341,  62]],
#
#        [[341,  61]],
#
#        [[342,  60]],
#
#        [[342,  58]],
#
#        [[343,  57]],
#
#        [[343,  55]],
#
#        [[344,  54]],
#
#        [[344,  53]],
#
#        [[345,  52]],
#
#        [[345,  51]],
#
#        [[346,  50]],
#
#        [[346,  48]],
#
#        [[347,  47]],
#
#        [[347,  46]],
#
#        [[349,  44]],
#
#        [[349,  42]],
#
#        [[351,  40]],
#
#        [[351,  39]],
#
#        [[352,  38]],
#
#        [[352,  37]],
#
#        [[353,  36]],
#
#        [[353,  35]],
#
#        [[355,  33]],
#
#        [[355,  32]],
#
#        [[356,  31]],
#
#        [[356,  30]]], dtype=int32), array([[[358,  28]],
#
#        [[359,  27]],
#
#        [[360,  28]],
#
#        [[359,  29]]], dtype=int32), array([[[359,  26]],
#
#        [[360,  25]],
#
#        [[361,  26]],
#
#        [[360,  27]]], dtype=int32), array([[[361,  23]],
#
#        [[362,  22]],
#
#        [[363,  23]],
#
#        [[362,  24]]], dtype=int32), array([[[362,  21]],
#
#        [[363,  20]],
#
#        [[364,  21]],
#
#        [[363,  22]]], dtype=int32), array([[[363,  20]],
#
#        [[364,  19]],
#
#        [[365,  20]],
#
#        [[364,  21]]], dtype=int32), array([[[364,  19]],
#
#        [[365,  18]],
#
#        [[366,  19]],
#
#        [[365,  20]]], dtype=int32), array([[[400,  18]],
#
#        [[401,  17]],
#
#        [[403,  17]],
#
#        [[406,  20]],
#
#        [[406,  21]],
#
#        [[407,  22]],
#
#        [[407,  25]],
#
#        [[408,  26]],
#
#        [[408,  28]],
#
#        [[409,  29]],
#
#        [[409,  31]],
#
#        [[410,  32]],
#
#        [[410,  35]],
#
#        [[411,  36]],
#
#        [[411,  38]],
#
#        [[412,  39]],
#
#        [[412,  41]],
#
#        [[413,  42]],
#
#        [[413,  45]],
#
#        [[414,  46]],
#
#        [[414,  47]],
#
#        [[415,  48]],
#
#        [[415,  51]],
#
#        [[416,  52]],
#
#        [[416,  56]],
#
#        [[417,  57]],
#
#        [[417,  59]],
#
#        [[418,  60]],
#
#        [[418,  64]],
#
#        [[419,  65]],
#
#        [[419,  69]],
#
#        [[420,  70]],
#
#        [[420,  76]],
#
#        [[421,  77]],
#
#        [[421,  81]],
#
#        [[422,  82]],
#
#        [[422,  89]],
#
#        [[420,  91]],
#
#        [[419,  90]],
#
#        [[419,  91]],
#
#        [[418,  92]],
#
#        [[418,  93]],
#
#        [[417,  94]],
#
#        [[417,  96]],
#
#        [[415,  98]],
#
#        [[412,  95]],
#
#        [[412,  94]],
#
#        [[413,  93]],
#
#        [[414,  94]],
#
#        [[415,  94]],
#
#        [[414,  93]],
#
#        [[414,  90]],
#
#        [[413,  90]],
#
#        [[412,  91]],
#
#        [[411,  91]],
#
#        [[410,  90]],
#
#        [[410,  83]],
#
#        [[409,  82]],
#
#        [[409,  81]],
#
#        [[408,  80]],
#
#        [[408,  73]],
#
#        [[407,  72]],
#
#        [[407,  71]],
#
#        [[408,  70]],
#
#        [[408,  66]],
#
#        [[407,  65]],
#
#        [[407,  64]],
#
#        [[406,  63]],
#
#        [[406,  58]],
#
#        [[406,  67]],
#
#        [[407,  68]],
#
#        [[407,  73]],
#
#        [[406,  74]],
#
#        [[406,  99]],
#
#        [[405, 100]],
#
#        [[405, 102]],
#
#        [[407, 104]],
#
#        [[407, 105]],
#
#        [[408, 106]],
#
#        [[409, 106]],
#
#        [[411, 108]],
#
#        [[412, 108]],
#
#        [[413, 109]],
#
#        [[414, 109]],
#
#        [[415, 110]],
#
#        [[412, 113]],
#
#        [[411, 113]],
#
#        [[411, 114]],
#
#        [[409, 116]],
#
#        [[409, 119]],
#
#        [[408, 120]],
#
#        [[406, 118]],
#
#        [[406, 117]],
#
#        [[403, 114]],
#
#        [[402, 114]],
#
#        [[402, 115]],
#
#        [[404, 117]],
#
#        [[403, 118]],
#
#        [[402, 118]],
#
#        [[401, 117]],
#
#        [[399, 117]],
#
#        [[398, 116]],
#
#        [[386, 116]],
#
#        [[385, 117]],
#
#        [[382, 117]],
#
#        [[381, 118]],
#
#        [[380, 118]],
#
#        [[379, 117]],
#
#        [[378, 117]],
#
#        [[377, 116]],
#
#        [[374, 116]],
#
#        [[373, 115]],
#
#        [[369, 115]],
#
#        [[368, 114]],
#
#        [[367, 114]],
#
#        [[365, 112]],
#
#        [[366, 111]],
#
#        [[366, 109]],
#
#        [[367, 108]],
#
#        [[368, 109]],
#
#        [[368, 110]],
#
#        [[370, 110]],
#
#        [[371, 111]],
#
#        [[372, 111]],
#
#        [[373, 112]],
#
#        [[375, 112]],
#
#        [[376, 113]],
#
#        [[378, 113]],
#
#        [[379, 114]],
#
#        [[384, 114]],
#
#        [[385, 113]],
#
#        [[386, 113]],
#
#        [[387, 112]],
#
#        [[397, 112]],
#
#        [[398, 113]],
#
#        [[400, 113]],
#
#        [[399, 112]],
#
#        [[381, 112]],
#
#        [[380, 111]],
#
#        [[377, 111]],
#
#        [[376, 110]],
#
#        [[374, 110]],
#
#        [[373, 109]],
#
#        [[368, 109]],
#
#        [[367, 108]],
#
#        [[367, 107]],
#
#        [[370, 104]],
#
#        [[372, 104]],
#
#        [[373, 103]],
#
#        [[374, 103]],
#
#        [[374, 102]],
#
#        [[377,  99]],
#
#        [[376,  98]],
#
#        [[376,  97]],
#
#        [[378,  95]],
#
#        [[380,  95]],
#
#        [[381,  94]],
#
#        [[382,  94]],
#
#        [[383,  95]],
#
#        [[386,  95]],
#
#        [[387,  96]],
#
#        [[385,  98]],
#
#        [[383,  98]],
#
#        [[384,  99]],
#
#        [[388,  99]],
#
#        [[389,  98]],
#
#        [[390,  99]],
#
#        [[390, 100]],
#
#        [[391, 100]],
#
#        [[392, 101]],
#
#        [[393, 101]],
#
#        [[393,  99]],
#
#        [[394,  98]],
#
#        [[397,  98]],
#
#        [[398,  99]],
#
#        [[398, 100]],
#
#        [[398,  99]],
#
#        [[399,  98]],
#
#        [[399,  97]],
#
#        [[400,  96]],
#
#        [[401,  96]],
#
#        [[402,  97]],
#
#        [[403,  97]],
#
#        [[403,  77]],
#
#        [[404,  76]],
#
#        [[403,  75]],
#
#        [[403,  72]],
#
#        [[404,  71]],
#
#        [[404,  69]],
#
#        [[403,  68]],
#
#        [[403,  66]],
#
#        [[404,  65]],
#
#        [[404,  64]],
#
#        [[403,  63]],
#
#        [[403,  61]],
#
#        [[404,  60]],
#
#        [[404,  56]],
#
#        [[403,  55]],
#
#        [[403,  28]],
#
#        [[403,  31]],
#
#        [[402,  32]],
#
#        [[402,  36]],
#
#        [[401,  37]],
#
#        [[401,  38]],
#
#        [[402,  39]],
#
#        [[402,  40]],
#
#        [[400,  42]],
#
#        [[400,  43]],
#
#        [[401,  44]],
#
#        [[401,  50]],
#
#        [[402,  51]],
#
#        [[402,  55]],
#
#        [[401,  56]],
#
#        [[401,  60]],
#
#        [[400,  61]],
#
#        [[400,  67]],
#
#        [[399,  68]],
#
#        [[400,  69]],
#
#        [[400,  79]],
#
#        [[401,  80]],
#
#        [[401,  82]],
#
#        [[400,  83]],
#
#        [[401,  84]],
#
#        [[401,  88]],
#
#        [[400,  89]],
#
#        [[401,  90]],
#
#        [[401,  92]],
#
#        [[399,  94]],
#
#        [[397,  94]],
#
#        [[396,  95]],
#
#        [[395,  95]],
#
#        [[394,  96]],
#
#        [[393,  95]],
#
#        [[392,  95]],
#
#        [[391,  94]],
#
#        [[390,  94]],
#
#        [[389,  95]],
#
#        [[388,  95]],
#
#        [[387,  94]],
#
#        [[387,  90]],
#
#        [[388,  89]],
#
#        [[388,  83]],
#
#        [[389,  82]],
#
#        [[389,  76]],
#
#        [[390,  75]],
#
#        [[390,  65]],
#
#        [[391,  64]],
#
#        [[391,  56]],
#
#        [[392,  55]],
#
#        [[392,  51]],
#
#        [[393,  50]],
#
#        [[393,  44]],
#
#        [[394,  43]],
#
#        [[394,  37]],
#
#        [[395,  36]],
#
#        [[395,  32]],
#
#        [[396,  31]],
#
#        [[396,  28]],
#
#        [[397,  27]],
#
#        [[397,  25]],
#
#        [[398,  24]],
#
#        [[398,  22]],
#
#        [[399,  21]],
#
#        [[399,  20]],
#
#        [[400,  19]]], dtype=int32), array([[[365,  18]],
#
#        [[366,  17]],
#
#        [[367,  18]],
#
#        [[366,  19]]], dtype=int32), array([[[366,  16]],
#
#        [[367,  15]],
#
#        [[368,  15]],
#
#        [[369,  16]],
#
#        [[367,  18]],
#
#        [[366,  17]]], dtype=int32), array([[[  0,   0]],
#
#        [[  0, 499]],
#
#        [[769, 499]],
#
#        [[769,   0]]], dtype=int32))

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
im =cv2.imread('rectangle.png')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
thresh = cv2.adaptiveThreshold(imgray,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

# %%
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2),plt.imshow(im,cmap='gray')
plt.title('Laplacian'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3),plt.imshow(im,cmap='gray')
plt.title('Sobel X'),plt.xticks([]),plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, 2, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

# %%
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2),plt.imshow(img0,cmap='gray')
plt.title('Laplacian'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3),plt.imshow(img1,cmap='gray')
plt.title('Sobel X'),plt.xticks([]),plt.yticks([])
plt.show()

# %%
print(contours)
# Out:
# (array([[[  0,   0]],
#
#        [[  0, 399]],
#
#        [[399, 399]],
#
#        [[399,   0]]], dtype=int32), array([[[361, 102]],
#
#        [[362, 101]],
#
#        [[363, 102]],
#
#        [[362, 103]]], dtype=int32), array([[[ 40, 100]],
#
#        [[ 41,  99]],
#
#        [[ 42,  99]],
#
#        [[ 43, 100]],
#
#        [[358, 100]],
#
#        [[359,  99]],
#
#        [[361, 101]],
#
#        [[361, 102]],
#
#        [[360, 103]],
#
#        [[360, 283]],
#
#        [[360, 104]],
#
#        [[361, 103]],
#
#        [[362, 104]],
#
#        [[362, 284]],
#
#        [[365, 284]],
#
#        [[367, 286]],
#
#        [[367, 294]],
#
#        [[366, 295]],
#
#        [[366, 296]],
#
#        [[362, 300]],
#
#        [[361, 300]],
#
#        [[360, 301]],
#
#        [[356, 301]],
#
#        [[355, 302]],
#
#        [[ 41, 302]],
#
#        [[ 34, 295]],
#
#        [[ 34, 294]],
#
#        [[ 33, 293]],
#
#        [[ 33, 286]],
#
#        [[ 35, 284]],
#
#        [[ 37, 284]],
#
#        [[ 38, 285]],
#
#        [[ 39, 285]],
#
#        [[ 39, 102]],
#
#        [[ 40, 101]]], dtype=int32), array([[[316, 297]],
#
#        [[320, 297]]], dtype=int32), array([[[237, 297]],
#
#        [[241, 297]]], dtype=int32), array([[[166, 297]],
#
#        [[170, 297]]], dtype=int32), array([[[ 87, 297]],
#
#        [[ 91, 297]]], dtype=int32), array([[[ 38, 293]]], dtype=int32), array([[[360, 286]],
#
#        [[360, 291]],
#
#        [[359, 292]],
#
#        [[ 42, 292]],
#
#        [[ 41, 291]],
#
#        [[ 41, 287]],
#
#        [[ 41, 291]],
#
#        [[ 40, 292]],
#
#        [[ 39, 291]],
#
#        [[ 39, 287]],
#
#        [[ 38, 287]],
#
#        [[ 38, 291]],
#
#        [[ 39, 291]],
#
#        [[ 40, 292]],
#
#        [[ 40, 294]],
#
#        [[ 41, 295]],
#
#        [[ 52, 295]],
#
#        [[ 53, 296]],
#
#        [[ 52, 297]],
#
#        [[ 42, 297]],
#
#        [[ 52, 297]],
#
#        [[ 53, 296]],
#
#        [[ 54, 296]],
#
#        [[ 55, 297]],
#
#        [[ 60, 297]],
#
#        [[ 61, 296]],
#
#        [[ 62, 296]],
#
#        [[ 63, 297]],
#
#        [[ 68, 297]],
#
#        [[ 69, 296]],
#
#        [[ 70, 296]],
#
#        [[ 71, 297]],
#
#        [[ 76, 297]],
#
#        [[ 77, 296]],
#
#        [[ 78, 296]],
#
#        [[ 79, 297]],
#
#        [[ 83, 297]],
#
#        [[ 79, 297]],
#
#        [[ 78, 296]],
#
#        [[ 79, 295]],
#
#        [[ 84, 295]],
#
#        [[ 85, 296]],
#
#        [[ 86, 295]],
#
#        [[ 92, 295]],
#
#        [[ 93, 296]],
#
#        [[ 94, 295]],
#
#        [[ 99, 295]],
#
#        [[100, 296]],
#
#        [[ 99, 297]],
#
#        [[ 95, 297]],
#
#        [[ 99, 297]],
#
#        [[100, 296]],
#
#        [[101, 296]],
#
#        [[102, 295]],
#
#        [[107, 295]],
#
#        [[108, 296]],
#
#        [[107, 297]],
#
#        [[103, 297]],
#
#        [[107, 297]],
#
#        [[108, 296]],
#
#        [[109, 296]],
#
#        [[110, 297]],
#
#        [[115, 297]],
#
#        [[116, 296]],
#
#        [[117, 296]],
#
#        [[118, 297]],
#
#        [[123, 297]],
#
#        [[124, 296]],
#
#        [[125, 296]],
#
#        [[126, 297]],
#
#        [[131, 297]],
#
#        [[132, 296]],
#
#        [[133, 296]],
#
#        [[134, 297]],
#
#        [[139, 297]],
#
#        [[140, 296]],
#
#        [[141, 296]],
#
#        [[142, 297]],
#
#        [[147, 297]],
#
#        [[148, 296]],
#
#        [[149, 296]],
#
#        [[150, 297]],
#
#        [[155, 297]],
#
#        [[156, 296]],
#
#        [[157, 296]],
#
#        [[158, 297]],
#
#        [[162, 297]],
#
#        [[158, 297]],
#
#        [[157, 296]],
#
#        [[158, 295]],
#
#        [[163, 295]],
#
#        [[164, 296]],
#
#        [[165, 295]],
#
#        [[171, 295]],
#
#        [[172, 296]],
#
#        [[173, 295]],
#
#        [[178, 295]],
#
#        [[179, 296]],
#
#        [[178, 297]],
#
#        [[174, 297]],
#
#        [[178, 297]],
#
#        [[179, 296]],
#
#        [[180, 296]],
#
#        [[181, 297]],
#
#        [[186, 297]],
#
#        [[187, 296]],
#
#        [[188, 296]],
#
#        [[189, 297]],
#
#        [[194, 297]],
#
#        [[195, 296]],
#
#        [[196, 296]],
#
#        [[197, 297]],
#
#        [[202, 297]],
#
#        [[203, 296]],
#
#        [[204, 296]],
#
#        [[205, 297]],
#
#        [[210, 297]],
#
#        [[211, 296]],
#
#        [[212, 296]],
#
#        [[213, 297]],
#
#        [[218, 297]],
#
#        [[219, 296]],
#
#        [[220, 296]],
#
#        [[221, 297]],
#
#        [[226, 297]],
#
#        [[227, 296]],
#
#        [[228, 296]],
#
#        [[229, 297]],
#
#        [[233, 297]],
#
#        [[229, 297]],
#
#        [[228, 296]],
#
#        [[229, 295]],
#
#        [[234, 295]],
#
#        [[235, 296]],
#
#        [[236, 295]],
#
#        [[242, 295]],
#
#        [[243, 296]],
#
#        [[244, 295]],
#
#        [[249, 295]],
#
#        [[250, 296]],
#
#        [[249, 297]],
#
#        [[245, 297]],
#
#        [[249, 297]],
#
#        [[250, 296]],
#
#        [[251, 296]],
#
#        [[252, 295]],
#
#        [[257, 295]],
#
#        [[258, 296]],
#
#        [[257, 297]],
#
#        [[253, 297]],
#
#        [[257, 297]],
#
#        [[258, 296]],
#
#        [[259, 296]],
#
#        [[260, 297]],
#
#        [[265, 297]],
#
#        [[266, 296]],
#
#        [[267, 296]],
#
#        [[268, 297]],
#
#        [[273, 297]],
#
#        [[274, 296]],
#
#        [[275, 296]],
#
#        [[276, 297]],
#
#        [[281, 297]],
#
#        [[282, 296]],
#
#        [[283, 296]],
#
#        [[284, 297]],
#
#        [[289, 297]],
#
#        [[290, 296]],
#
#        [[291, 296]],
#
#        [[292, 297]],
#
#        [[297, 297]],
#
#        [[298, 296]],
#
#        [[299, 296]],
#
#        [[300, 297]],
#
#        [[305, 297]],
#
#        [[306, 296]],
#
#        [[307, 296]],
#
#        [[308, 297]],
#
#        [[312, 297]],
#
#        [[308, 297]],
#
#        [[307, 296]],
#
#        [[308, 295]],
#
#        [[313, 295]],
#
#        [[314, 296]],
#
#        [[315, 295]],
#
#        [[321, 295]],
#
#        [[322, 296]],
#
#        [[323, 295]],
#
#        [[328, 295]],
#
#        [[329, 296]],
#
#        [[328, 297]],
#
#        [[324, 297]],
#
#        [[328, 297]],
#
#        [[329, 296]],
#
#        [[330, 296]],
#
#        [[331, 297]],
#
#        [[336, 297]],
#
#        [[337, 296]],
#
#        [[338, 296]],
#
#        [[339, 297]],
#
#        [[344, 297]],
#
#        [[345, 296]],
#
#        [[346, 296]],
#
#        [[347, 297]],
#
#        [[352, 297]],
#
#        [[353, 296]],
#
#        [[359, 296]],
#
#        [[362, 293]],
#
#        [[362, 286]]], dtype=int32), array([[[346, 296]],
#
#        [[347, 295]],
#
#        [[352, 295]],
#
#        [[353, 296]],
#
#        [[352, 297]],
#
#        [[347, 297]]], dtype=int32), array([[[338, 296]],
#
#        [[339, 295]],
#
#        [[344, 295]],
#
#        [[345, 296]],
#
#        [[344, 297]],
#
#        [[339, 297]]], dtype=int32), array([[[330, 296]],
#
#        [[331, 295]],
#
#        [[336, 295]],
#
#        [[337, 296]],
#
#        [[336, 297]],
#
#        [[331, 297]]], dtype=int32), array([[[299, 296]],
#
#        [[300, 295]],
#
#        [[305, 295]],
#
#        [[306, 296]],
#
#        [[305, 297]],
#
#        [[300, 297]]], dtype=int32), array([[[291, 296]],
#
#        [[292, 295]],
#
#        [[297, 295]],
#
#        [[298, 296]],
#
#        [[297, 297]],
#
#        [[292, 297]]], dtype=int32), array([[[283, 296]],
#
#        [[284, 295]],
#
#        [[289, 295]],
#
#        [[290, 296]],
#
#        [[289, 297]],
#
#        [[284, 297]]], dtype=int32), array([[[275, 296]],
#
#        [[276, 295]],
#
#        [[281, 295]],
#
#        [[282, 296]],
#
#        [[281, 297]],
#
#        [[276, 297]]], dtype=int32), array([[[267, 296]],
#
#        [[268, 295]],
#
#        [[273, 295]],
#
#        [[274, 296]],
#
#        [[273, 297]],
#
#        [[268, 297]]], dtype=int32), array([[[259, 296]],
#
#        [[260, 295]],
#
#        [[265, 295]],
#
#        [[266, 296]],
#
#        [[265, 297]],
#
#        [[260, 297]]], dtype=int32), array([[[220, 296]],
#
#        [[221, 295]],
#
#        [[226, 295]],
#
#        [[227, 296]],
#
#        [[226, 297]],
#
#        [[221, 297]]], dtype=int32), array([[[212, 296]],
#
#        [[213, 295]],
#
#        [[218, 295]],
#
#        [[219, 296]],
#
#        [[218, 297]],
#
#        [[213, 297]]], dtype=int32), array([[[204, 296]],
#
#        [[205, 295]],
#
#        [[210, 295]],
#
#        [[211, 296]],
#
#        [[210, 297]],
#
#        [[205, 297]]], dtype=int32), array([[[196, 296]],
#
#        [[197, 295]],
#
#        [[202, 295]],
#
#        [[203, 296]],
#
#        [[202, 297]],
#
#        [[197, 297]]], dtype=int32), array([[[188, 296]],
#
#        [[189, 295]],
#
#        [[194, 295]],
#
#        [[195, 296]],
#
#        [[194, 297]],
#
#        [[189, 297]]], dtype=int32), array([[[180, 296]],
#
#        [[181, 295]],
#
#        [[186, 295]],
#
#        [[187, 296]],
#
#        [[186, 297]],
#
#        [[181, 297]]], dtype=int32), array([[[149, 296]],
#
#        [[150, 295]],
#
#        [[155, 295]],
#
#        [[156, 296]],
#
#        [[155, 297]],
#
#        [[150, 297]]], dtype=int32), array([[[141, 296]],
#
#        [[142, 295]],
#
#        [[147, 295]],
#
#        [[148, 296]],
#
#        [[147, 297]],
#
#        [[142, 297]]], dtype=int32), array([[[133, 296]],
#
#        [[134, 295]],
#
#        [[139, 295]],
#
#        [[140, 296]],
#
#        [[139, 297]],
#
#        [[134, 297]]], dtype=int32), array([[[125, 296]],
#
#        [[126, 295]],
#
#        [[131, 295]],
#
#        [[132, 296]],
#
#        [[131, 297]],
#
#        [[126, 297]]], dtype=int32), array([[[117, 296]],
#
#        [[118, 295]],
#
#        [[123, 295]],
#
#        [[124, 296]],
#
#        [[123, 297]],
#
#        [[118, 297]]], dtype=int32), array([[[109, 296]],
#
#        [[110, 295]],
#
#        [[115, 295]],
#
#        [[116, 296]],
#
#        [[115, 297]],
#
#        [[110, 297]]], dtype=int32), array([[[ 70, 296]],
#
#        [[ 71, 295]],
#
#        [[ 76, 295]],
#
#        [[ 77, 296]],
#
#        [[ 76, 297]],
#
#        [[ 71, 297]]], dtype=int32), array([[[ 62, 296]],
#
#        [[ 63, 295]],
#
#        [[ 68, 295]],
#
#        [[ 69, 296]],
#
#        [[ 68, 297]],
#
#        [[ 63, 297]]], dtype=int32), array([[[ 54, 296]],
#
#        [[ 55, 295]],
#
#        [[ 60, 295]],
#
#        [[ 61, 296]],
#
#        [[ 60, 297]],
#
#        [[ 55, 297]]], dtype=int32), array([[[360, 287]],
#
#        [[361, 286]],
#
#        [[362, 287]],
#
#        [[362, 291]],
#
#        [[361, 292]],
#
#        [[360, 291]]], dtype=int32), array([[[ 43, 103]],
#
#        [[ 43, 288]],
#
#        [[ 44, 289]],
#
#        [[ 44, 290]],
#
#        [[357, 290]],
#
#        [[357, 287]],
#
#        [[358, 286]],
#
#        [[358, 103]]], dtype=int32), array([[[ 43,  96]],
#
#        [[ 44,  95]],
#
#        [[357,  95]],
#
#        [[359,  97]],
#
#        [[359,  99]],
#
#        [[358, 100]],
#
#        [[ 44, 100]],
#
#        [[ 43,  99]]], dtype=int32))

# %%
cnt = contours[2]
M = cv2.moments(cnt)
print(M)
# Out:
# {'m00': 65370.5, 'm10': 13103608.666666666, 'm01': 13151215.5, 'm20': 3197256720.25, 'm11': 2636022409.7916665, 'm02': 2868596609.75, 'm30': 869656461189.3, 'm21': 643374720610.4667, 'm12': 574933200511.9333, 'm03': 666738720395.65, 'mu20': 570619933.1802707, 'mu11': -157233.97732686996, 'mu02': 222839439.04700327, 'mu30': -1281563.3732910156, 'mu21': 214710027.48236084, 'mu12': -17759949.608444214, 'mu03': -26122568.747680664, 'nu20': 0.13353137622695896, 'nu11': -3.6794489924456324e-05, 'nu02': 0.052146893656077956, 'nu30': -1.172966395113851e-06, 'nu21': 0.00019651595245270126, 'nu12': -1.6255008924080726e-05, 'nu03': -2.3908997349382615e-05}

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

# %%
img0 = cv2.rectangle(img0, (cx-2,cy-2),(cx+2,cy+2),(0,0,255),2)

# %%
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,2),plt.imshow(img0,cmap='gray')
plt.title('Laplacian'),plt.xticks([]),plt.yticks([])
plt.subplot(1,3,3),plt.imshow(img1,cmap='gray')
plt.title('Sobel X'),plt.xticks([]),plt.yticks([])
plt.show()
